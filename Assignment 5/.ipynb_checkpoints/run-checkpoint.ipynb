# %% [markdown]
# <center>
# <h1>CSE 6363-007: Machine Learning Assignment 5</h1>
#     <h2>Name: Ananthula, Vineeth Kumar. UTA ID: 1001953922</h2>
# </center>

# %%
from scipy import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import re

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
# read titanic train and test data
train = pd.read_csv('./input/train.csv')
test = pd.read_csv('./input/test.csv')

print("train shape: {} test shape: {}".format(train.shape, test.shape))
# Showing overview of the train dataset
train.head(3)
# Out:
# train shape: (1047, 11) test shape: (262, 11)
#    Pclass  Survived                              Name     Sex   Age  SibSp  \
# 0       1         1    Hays, Miss. Margaret Bechstein  female  24.0      0
# 1       3         0  Holm, Mr. John Fredrik Alexander    male  43.0      0
# 2       3         0           Hansen, Mr. Claus Peter    male  41.0      2
#
#    Parch  Ticket     Fare Cabin Embarked
# 0      0   11767  83.1583   C54        C
# 1      0  C 7075   6.4500   NaN        S
# 2      0  350026  14.1083   NaN        S

# %% [markdown]
# ## Deal with missing values and transform to discrete variables

# %%
# referred from: https://www.kaggle.com/dmilla/introduction-to-decision-trees-titanic-dataset
full_data = [train, test]

# Feature that tells whether a passenger had a cabin on the Titanic
train['Has_Cabin'] = train["Cabin"].apply(lambda x: 0 if type(x) == float else 1)
test['Has_Cabin'] = test["Cabin"].apply(lambda x: 0 if type(x) == float else 1)

# Create new feature FamilySize as a combination of SibSp and Parch
for dataset in full_data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
# Create new feature IsAlone from FamilySize
for dataset in full_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
# Remove all NULLS in the Embarked column
for dataset in full_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
# Remove all NULLS in the Fare column
for dataset in full_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

# Remove all NULLS in the Age column
for dataset in full_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    # Next line has been improved to avoid warning
    dataset.loc[np.isnan(dataset['Age']), 'Age'] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)

# Define function to extract titles from passenger names
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    # If the title exists, extract and return it.
    if title_search:
        return title_search.group(1)
    return ""

for dataset in full_data:
    dataset['Title'] = dataset['Name'].apply(get_title)
# Group all non-common titles into one single grouping "Rare"
for dataset in full_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

for dataset in full_data:
    # Mapping Sex
    dataset['Sex'] = dataset['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
    
    # Mapping titles
    title_mapping = {"Mr": 1, "Master": 2, "Mrs": 3, "Miss": 4, "Rare": 5}
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

    # Mapping Embarked
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
    
    # Mapping Fare
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare'] = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)
    
    # Mapping Age
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

# %%
drop_elements = ['Name', 'Ticket', 'Cabin', 'SibSp']
train = train.drop(drop_elements, axis = 1)
test  = test.drop(drop_elements, axis = 1)

# %%
train.head()
# Out:
#    Pclass  Survived  Sex  Age  Parch  Fare  Embarked  Has_Cabin  FamilySize  \
# 0       1         1    0    1      0     3         1          1           1
# 1       3         0    1    2      0     0         0          0           1
# 2       3         0    1    2      0     1         0          0           3
# 3       3         0    1    2      0     0         2          0           1
# 4       2         0    1    2      0     1         0          0           1
#
#    IsAlone  Title
# 0        1      4
# 1        1      1
# 2        0      1
# 3        1      1
# 4        1      1

# %%
X = train.drop(['Survived'], axis=1)
y = train["Survived"]
X_test = test.drop(['Survived'], axis=1)
y_test = test["Survived"]
print("train: {}, test: {}".format(X.shape, X_test.shape))
print((np.array(X)).shape[1])
# Out:
# train: (1047, 10), test: (262, 10)
# 10

# %%
def accuracy(y_gt, y_pred):
    return np.sum(y_gt == y_pred) / y_gt.shape[0]

# %%
print("Survived: {:.4f}, Not Survivied: {:.4f}".format(y.sum() / len(y), 1 - y.sum() / len(y)))
# Out:
# Survived: 0.3878, Not Survivied: 0.6122

# %% [markdown]
# # Decision Tree

# %%
from decision_tree import DecisionTree

dt = DecisionTree(criterion='gini', max_depth=4, min_samples_leaf=4, sample_feature=False)
dt.fit(X, y)
print(dt._tree)
y_train_pred = dt.predict(X)

print("Accuracy on train set: {}".format(accuracy(y, y_train_pred)))

# Plot the decision tree to get an intuition about how it makes decision
plt.figure(figsize=(20, 10))
dt.show()
# Out:
# {'Title': {1: {'Has_Cabin': {0: {'Pclass': {1: 0, 2: 0, 3: 0}}, 1: {'Fare': {0: 0, 1: 0, 2: 0, 3: 0}}}}, 2: {'FamilySize': {1: 0, 2: 1, 3: {'Pclass': {1: 1, 2: 1, 3: 1}}, 4: 1, 5: 0, 6: 0, 7: 0, 8: 0, 11: 0}}, 3: {'Pclass': {1: {'FamilySize': {1: 1, 2: 1, 3: 1, 4: 1}}, 2: {'Age': {0: 1, 1: 1, 2: 1, 3: 1}}, 3: {'FamilySize': {1: 1, 2: 1, 3: 1, 4: 1, 5: 0, 6: 0, 7: 1, 8: 0, 11: 0}}}}, 4: {'Pclass': {1: {'FamilySize': {1: 1, 2: 1, 3: 1, 4: 0, 5: 1, 6: 1}}, 2: {'Fare': {1: 1, 2: 1, 3: 1}}, 3: {'FamilySize': {1: 1, 2: 0, 3: 1, 4: 1, 5: 0, 6: 0, 7: 0, 8: 0, 11: 0}}}}, 5: {'Has_Cabin': {0: {'FamilySize': {1: 0, 2: 0, 3: 0}}, 1: {'Age': {1: 1, 2: 0, 3: 1, 4: 0}}}}}}
# Accuracy on train set: 0.8223495702005731

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=2020)
criters=['entropy', 'ratioInfoGain','gini']
depths=[3, 4, 5, 6, 7, 8]
leaves=[1, 4, 8, 16, 32, 64]
bestCriter=criters[0]
bestDepth=depths[0]
bestLeaf=leaves[0]
bestScore=0.0

for depth in depths:
    for leaf in leaves:
        for criter in criters:
            print('{} {} {}'.format(depth, leaf, criter))
            dt = DecisionTree(criterion=criter, max_depth=depth, min_samples_leaf=leaf, sample_feature=False)
            pred=np.zeros(len(X))
            for train_indice, valid_indice in kf.split(X, y):
                X_train_fold, y_train_fold = X.loc[train_indice], y.loc[train_indice]
                X_val_fold, y_val_fold = X.loc[valid_indice], y.loc[valid_indice]
               # print(X_train_fold.shape, X_val_fold.shape)
                dt.fit(X_train_fold, y_train_fold)
                pred[valid_indice]=dt.predict(X_val_fold)
            score=accuracy(y, pred)
            if score>bestScore:
                bestScore=score
                bestCriter=criter
                bestDepth=depth
                bestLeaf=leaf
            print("Accuracy on validation set: {}".format(score))            
print('{} {} {}'.format(bestCriter, bestDepth, bestLeaf))
dt=DecisionTree(criterion=bestCriter, max_depth=bestDepth, min_samples_leaf=bestLeaf, sample_feature=False)

dt.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, dt.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, dt.predict(X_test))))
# Out:
# 3 1 entropy
# Accuracy on validation set: 0.7908309455587392
# 3 1 ratioInfoGain
# Accuracy on validation set: 0.7774594078319007
# 3 1 gini
# Accuracy on validation set: 0.789875835721108
# 3 4 entropy
# Accuracy on validation set: 0.789875835721108
# 3 4 ratioInfoGain
# Accuracy on validation set: 0.7774594078319007
# 3 4 gini
# Accuracy on validation set: 0.7908309455587392
# 3 8 entropy
# Accuracy on validation set: 0.7889207258834766
# 3 8 ratioInfoGain
# Accuracy on validation set: 0.7774594078319007
# 3 8 gini
# Accuracy on validation set: 0.7917860553963706
# 3 16 entropy
# Accuracy on validation set: 0.7870105062082139
# 3 16 ratioInfoGain
# Accuracy on validation set: 0.7774594078319007
# 3 16 gini
# Accuracy on validation set: 0.7870105062082139
# 3 32 entropy
# Accuracy on validation set: 0.7831900668576887
# 3 32 ratioInfoGain
# Accuracy on validation set: 0.7774594078319007
# 3 32 gini
# Accuracy on validation set: 0.7851002865329513
# 3 64 entropy
# Accuracy on validation set: 0.7640878701050621
# 3 64 ratioInfoGain
# Accuracy on validation set: 0.7774594078319007
# 3 64 gini
# Accuracy on validation set: 0.7659980897803247
# 4 1 entropy
# Accuracy on validation set: 0.7870105062082139
# 4 1 ratioInfoGain
# Accuracy on validation set: 0.8089780324737345
# 4 1 gini
# Accuracy on validation set: 0.7870105062082139
# 4 4 entropy
# Accuracy on validation set: 0.7841451766953199
# 4 4 ratioInfoGain
# Accuracy on validation set: 0.8089780324737345
# 4 4 gini
# Accuracy on validation set: 0.7841451766953199
# 4 8 entropy
# Accuracy on validation set: 0.789875835721108
# 4 8 ratioInfoGain
# Accuracy on validation set: 0.8089780324737345
# 4 8 gini
# Accuracy on validation set: 0.7870105062082139
# 4 16 entropy
# Accuracy on validation set: 0.7841451766953199
# 4 16 ratioInfoGain
# Accuracy on validation set: 0.8089780324737345
# 4 16 gini
# Accuracy on validation set: 0.7870105062082139
# 4 32 entropy
# Accuracy on validation set: 0.7908309455587392
# 4 32 ratioInfoGain
# Accuracy on validation set: 0.8099331423113658
# 4 32 gini
# Accuracy on validation set: 0.7889207258834766
# 4 64 entropy
# Accuracy on validation set: 0.775549188156638
# 4 64 ratioInfoGain
# Accuracy on validation set: 0.8089780324737345
# 4 64 gini
# Accuracy on validation set: 0.7736389684813754
# 5 1 entropy
# Accuracy on validation set: 0.7841451766953199
# 5 1 ratioInfoGain
# Accuracy on validation set: 0.789875835721108
# 5 1 gini
# Accuracy on validation set: 0.7870105062082139
# 5 4 entropy
# Accuracy on validation set: 0.7879656160458453
# 5 4 ratioInfoGain
# Accuracy on validation set: 0.7936962750716332
# 5 4 gini
# Accuracy on validation set: 0.789875835721108
# 5 8 entropy
# Accuracy on validation set: 0.7908309455587392
# 5 8 ratioInfoGain
# Accuracy on validation set: 0.7975167144221585
# 5 8 gini
# Accuracy on validation set: 0.789875835721108
# 5 16 entropy
# Accuracy on validation set: 0.7908309455587392
# 5 16 ratioInfoGain
# Accuracy on validation set: 0.7975167144221585
# 5 16 gini
# Accuracy on validation set: 0.7879656160458453
# 5 32 entropy
# Accuracy on validation set: 0.7860553963705826
# 5 32 ratioInfoGain
# Accuracy on validation set: 0.8022922636103151
# 5 32 gini
# Accuracy on validation set: 0.789875835721108
# 5 64 entropy
# Accuracy on validation set: 0.7745940783190067
# 5 64 ratioInfoGain
# Accuracy on validation set: 0.8013371537726839
# 5 64 gini
# Accuracy on validation set: 0.7745940783190067
# 6 1 entropy
# Accuracy on validation set: 0.772683858643744
# 6 1 ratioInfoGain
# Accuracy on validation set: 0.792741165234002
# 6 1 gini
# Accuracy on validation set: 0.766953199617956
# 6 4 entropy
# Accuracy on validation set: 0.7765042979942693
# 6 4 ratioInfoGain
# Accuracy on validation set: 0.7956064947468959
# 6 4 gini
# Accuracy on validation set: 0.7688634192932188
# 6 8 entropy
# Accuracy on validation set: 0.7831900668576887
# 6 8 ratioInfoGain
# Accuracy on validation set: 0.7936962750716332
# 6 8 gini
# Accuracy on validation set: 0.7774594078319007
# 6 16 entropy
# Accuracy on validation set: 0.7812798471824259
# 6 16 ratioInfoGain
# Accuracy on validation set: 0.7984718242597899
# 6 16 gini
# Accuracy on validation set: 0.772683858643744
# 6 32 entropy
# Accuracy on validation set: 0.7803247373447947
# 6 32 ratioInfoGain
# Accuracy on validation set: 0.8022922636103151
# 6 32 gini
# Accuracy on validation set: 0.7812798471824259
# 6 64 entropy
# Accuracy on validation set: 0.7765042979942693
# 6 64 ratioInfoGain
# Accuracy on validation set: 0.8003820439350525
# 6 64 gini
# Accuracy on validation set: 0.7707736389684814
# 7 1 entropy
# Accuracy on validation set: 0.7612225405921681
# 7 1 ratioInfoGain
# Accuracy on validation set: 0.7765042979942693
# 7 1 gini
# Accuracy on validation set: 0.7631327602674307
# 7 4 entropy
# Accuracy on validation set: 0.7707736389684814
# 7 4 ratioInfoGain
# Accuracy on validation set: 0.778414517669532
# 7 4 gini
# Accuracy on validation set: 0.76981852913085
# 7 8 entropy
# Accuracy on validation set: 0.7803247373447947
# 7 8 ratioInfoGain
# Accuracy on validation set: 0.7831900668576887
# 7 8 gini
# Accuracy on validation set: 0.7774594078319007
# 7 16 entropy
# Accuracy on validation set: 0.7851002865329513
# 7 16 ratioInfoGain
# Accuracy on validation set: 0.7870105062082139
# 7 16 gini
# Accuracy on validation set: 0.7745940783190067
# 7 32 entropy
# Accuracy on validation set: 0.7822349570200573
# 7 32 ratioInfoGain
# Accuracy on validation set: 0.7956064947468959
# 7 32 gini
# Accuracy on validation set: 0.7831900668576887
# 7 64 entropy
# Accuracy on validation set: 0.7765042979942693
# 7 64 ratioInfoGain
# Accuracy on validation set: 0.7965616045845272
# 7 64 gini
# Accuracy on validation set: 0.772683858643744
# 8 1 entropy
# Accuracy on validation set: 0.7640878701050621
# 8 1 ratioInfoGain
# Accuracy on validation set: 0.766953199617956
# 8 1 gini
# Accuracy on validation set: 0.7593123209169055
# 8 4 entropy
# Accuracy on validation set: 0.7707736389684814
# 8 4 ratioInfoGain
# Accuracy on validation set: 0.7707736389684814
# 8 4 gini
# Accuracy on validation set: 0.7745940783190067
# 8 8 entropy
# Accuracy on validation set: 0.7831900668576887
# 8 8 ratioInfoGain
# Accuracy on validation set: 0.778414517669532
# 8 8 gini
# Accuracy on validation set: 0.7793696275071633
# 8 16 entropy
# Accuracy on validation set: 0.7870105062082139
# 8 16 ratioInfoGain
# Accuracy on validation set: 0.7822349570200573
# 8 16 gini
# Accuracy on validation set: 0.775549188156638
# 8 32 entropy
# Accuracy on validation set: 0.7841451766953199
# 8 32 ratioInfoGain
# Accuracy on validation set: 0.7936962750716332
# 8 32 gini
# Accuracy on validation set: 0.7812798471824259
# 8 64 entropy
# Accuracy on validation set: 0.7774594078319007
# 8 64 ratioInfoGain
# Accuracy on validation set: 0.7946513849092646
# 8 64 gini
# Accuracy on validation set: 0.7717287488061128
# ratioInfoGain 4 32
# Accuracy on train set: 0.8127984718242598
# Accuracy on test set: 0.7900763358778626

# %%
# report the accuracy on test set

criters=['entropy', 'ratioInfoGain','gini']
depths=[3, 4, 5, 6, 7, 8]
leaves=[1, 4, 8, 16, 32, 64]
bestCriter=criters[0]
bestDepth=depths[0]
bestLeaf=leaves[0]
bestScore=0.0
for depth in depths:
    for leaf in leaves:
        for criter in criters:
            print('{} {} {}'.format(depth, leaf, criter))
            dt=DecisionTree(criterion=criter, max_depth=depth, min_samples_leaf=leaf, sample_feature=False)
            dt.fit(X, y)
            score=accuracy(y_test, dt.predict(X_test))
            if score > bestScore:
                bestScore=score
                bestCriter=criter
                bestDepth=depth
                bestLeaf=leaf
            print("Accuracy on test set: {}".format(score))
                
            
print('{} {} {}'.format(bestCriter, bestDepth, bestLeaf))
dt=DecisionTree(criterion=bestCriter, max_depth=bestDepth, min_samples_leaf=bestLeaf, sample_feature=False)

dt.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, dt.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, dt.predict(X_test))))
# Out:
# 3 1 entropy
# Accuracy on test set: 0.8129770992366412
# 3 1 ratioInfoGain
# Accuracy on test set: 0.7709923664122137
# 3 1 gini
# Accuracy on test set: 0.8129770992366412
# 3 4 entropy
# Accuracy on test set: 0.8129770992366412
# 3 4 ratioInfoGain
# Accuracy on test set: 0.7709923664122137
# 3 4 gini
# Accuracy on test set: 0.8129770992366412
# 3 8 entropy
# Accuracy on test set: 0.8129770992366412
# 3 8 ratioInfoGain
# Accuracy on test set: 0.7709923664122137
# 3 8 gini
# Accuracy on test set: 0.8129770992366412
# 3 16 entropy
# Accuracy on test set: 0.8129770992366412
# 3 16 ratioInfoGain
# Accuracy on test set: 0.7709923664122137
# 3 16 gini
# Accuracy on test set: 0.8129770992366412
# 3 32 entropy
# Accuracy on test set: 0.8129770992366412
# 3 32 ratioInfoGain
# Accuracy on test set: 0.7709923664122137
# 3 32 gini
# Accuracy on test set: 0.8129770992366412
# 3 64 entropy
# Accuracy on test set: 0.7900763358778626
# 3 64 ratioInfoGain
# Accuracy on test set: 0.7709923664122137
# 3 64 gini
# Accuracy on test set: 0.7900763358778626
# 4 1 entropy
# Accuracy on test set: 0.8091603053435115
# 4 1 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 4 1 gini
# Accuracy on test set: 0.8091603053435115
# 4 4 entropy
# Accuracy on test set: 0.8091603053435115
# 4 4 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 4 4 gini
# Accuracy on test set: 0.8091603053435115
# 4 8 entropy
# Accuracy on test set: 0.8091603053435115
# 4 8 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 4 8 gini
# Accuracy on test set: 0.8091603053435115
# 4 16 entropy
# Accuracy on test set: 0.8091603053435115
# 4 16 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 4 16 gini
# Accuracy on test set: 0.8091603053435115
# 4 32 entropy
# Accuracy on test set: 0.8091603053435115
# 4 32 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 4 32 gini
# Accuracy on test set: 0.8091603053435115
# 4 64 entropy
# Accuracy on test set: 0.7862595419847328
# 4 64 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 4 64 gini
# Accuracy on test set: 0.7862595419847328
# 5 1 entropy
# Accuracy on test set: 0.7824427480916031
# 5 1 ratioInfoGain
# Accuracy on test set: 0.7938931297709924
# 5 1 gini
# Accuracy on test set: 0.7862595419847328
# 5 4 entropy
# Accuracy on test set: 0.7824427480916031
# 5 4 ratioInfoGain
# Accuracy on test set: 0.7938931297709924
# 5 4 gini
# Accuracy on test set: 0.7862595419847328
# 5 8 entropy
# Accuracy on test set: 0.7824427480916031
# 5 8 ratioInfoGain
# Accuracy on test set: 0.8015267175572519
# 5 8 gini
# Accuracy on test set: 0.7862595419847328
# 5 16 entropy
# Accuracy on test set: 0.7977099236641222
# 5 16 ratioInfoGain
# Accuracy on test set: 0.7977099236641222
# 5 16 gini
# Accuracy on test set: 0.7938931297709924
# 5 32 entropy
# Accuracy on test set: 0.8015267175572519
# 5 32 ratioInfoGain
# Accuracy on test set: 0.7977099236641222
# 5 32 gini
# Accuracy on test set: 0.8015267175572519
# 5 64 entropy
# Accuracy on test set: 0.7748091603053435
# 5 64 ratioInfoGain
# Accuracy on test set: 0.7862595419847328
# 5 64 gini
# Accuracy on test set: 0.7786259541984732
# 6 1 entropy
# Accuracy on test set: 0.7977099236641222
# 6 1 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 6 1 gini
# Accuracy on test set: 0.8091603053435115
# 6 4 entropy
# Accuracy on test set: 0.7977099236641222
# 6 4 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 6 4 gini
# Accuracy on test set: 0.8053435114503816
# 6 8 entropy
# Accuracy on test set: 0.7938931297709924
# 6 8 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 6 8 gini
# Accuracy on test set: 0.7900763358778626
# 6 16 entropy
# Accuracy on test set: 0.7900763358778626
# 6 16 ratioInfoGain
# Accuracy on test set: 0.7824427480916031
# 6 16 gini
# Accuracy on test set: 0.7900763358778626
# 6 32 entropy
# Accuracy on test set: 0.8015267175572519
# 6 32 ratioInfoGain
# Accuracy on test set: 0.7938931297709924
# 6 32 gini
# Accuracy on test set: 0.7977099236641222
# 6 64 entropy
# Accuracy on test set: 0.7786259541984732
# 6 64 ratioInfoGain
# Accuracy on test set: 0.7824427480916031
# 6 64 gini
# Accuracy on test set: 0.7748091603053435
# 7 1 entropy
# Accuracy on test set: 0.7824427480916031
# 7 1 ratioInfoGain
# Accuracy on test set: 0.7977099236641222
# 7 1 gini
# Accuracy on test set: 0.7900763358778626
# 7 4 entropy
# Accuracy on test set: 0.7900763358778626
# 7 4 ratioInfoGain
# Accuracy on test set: 0.7977099236641222
# 7 4 gini
# Accuracy on test set: 0.8053435114503816
# 7 8 entropy
# Accuracy on test set: 0.7862595419847328
# 7 8 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 7 8 gini
# Accuracy on test set: 0.7938931297709924
# 7 16 entropy
# Accuracy on test set: 0.7900763358778626
# 7 16 ratioInfoGain
# Accuracy on test set: 0.7862595419847328
# 7 16 gini
# Accuracy on test set: 0.7900763358778626
# 7 32 entropy
# Accuracy on test set: 0.8015267175572519
# 7 32 ratioInfoGain
# Accuracy on test set: 0.7938931297709924
# 7 32 gini
# Accuracy on test set: 0.7977099236641222
# 7 64 entropy
# Accuracy on test set: 0.7786259541984732
# 7 64 ratioInfoGain
# Accuracy on test set: 0.7824427480916031
# 7 64 gini
# Accuracy on test set: 0.7748091603053435
# 8 1 entropy
# Accuracy on test set: 0.7786259541984732
# 8 1 ratioInfoGain
# Accuracy on test set: 0.7862595419847328
# 8 1 gini
# Accuracy on test set: 0.7938931297709924
# 8 4 entropy
# Accuracy on test set: 0.8015267175572519
# 8 4 ratioInfoGain
# Accuracy on test set: 0.8015267175572519
# 8 4 gini
# Accuracy on test set: 0.7977099236641222
# 8 8 entropy
# Accuracy on test set: 0.7862595419847328
# 8 8 ratioInfoGain
# Accuracy on test set: 0.7900763358778626
# 8 8 gini
# Accuracy on test set: 0.7938931297709924
# 8 16 entropy
# Accuracy on test set: 0.7977099236641222
# 8 16 ratioInfoGain
# Accuracy on test set: 0.7824427480916031
# 8 16 gini
# Accuracy on test set: 0.7938931297709924
# 8 32 entropy
# Accuracy on test set: 0.8053435114503816
# 8 32 ratioInfoGain
# Accuracy on test set: 0.7938931297709924
# 8 32 gini
# Accuracy on test set: 0.7977099236641222
# 8 64 entropy
# Accuracy on test set: 0.7824427480916031
# 8 64 ratioInfoGain
# Accuracy on test set: 0.7824427480916031
# 8 64 gini
# Accuracy on test set: 0.7748091603053435
# entropy 3 1
# Accuracy on train set: 0.8013371537726839
# Accuracy on test set: 0.8129770992366412

# %% [markdown]
# # Random Forest

# %%
from random_forest import RandomForest

base_learner = DecisionTree(criterion='ratioInfoGain', max_depth=6, min_samples_leaf=6, sample_feature=True)
rf = RandomForest(base_learner=base_learner, num_trees=100, min_features=2020)
rf.fit(X, y)

y_train_pred = rf.predict(X)

print("Accuracy on train set: {}".format(accuracy(y, y_train_pred)))
print("Accuracy on test set: {}".format(accuracy(y_test, rf.predict(X_test))))
# Out:
# Accuracy on train set: 0.8385864374403056
# Accuracy on test set: 0.8244274809160306

# %%
# hyper-parameters such as max_depth, and min_samples_in_leaf 
# according to the cross-validation result.
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=2020)
criters=['entropy', 'ratioInfoGain','gini']
depths=[3, 4, 5, 6, 7, 8]
leaves=[1, 4, 8, 16, 32, 64]
estimators=[10, 20, 40, 100]
bestCriter=criters[0]
bestDepth=depths[0]
bestLeaf=leaves[0]
best_estimator=estimators[0]
bestScore=0.0

for depth in depths:
    for leaf in leaves:
        for criter in criters:
            for estimator in estimators:
                print('{} {} {} {}'.format(depth, leaf, criter, estimator))
                base_learner = DecisionTree(criterion=criter, max_depth=depth, min_samples_leaf=leaf, sample_feature=True)
                rf = RandomForest(base_learner=base_learner, num_trees=estimator, min_features=2020)
                pred=np.zeros(len(X))
                for train_indice, valid_indice in kf.split(X, y):
                    X_train_fold, y_train_fold = X.loc[train_indice], y.loc[train_indice]
                    X_val_fold, y_val_fold = X.loc[valid_indice], y.loc[valid_indice]
                   # print(X_train_fold.shape, X_val_fold.shape)
                    rf.fit(X_train_fold, y_train_fold)
                    pred[valid_indice]=rf.predict(X_val_fold)
                score=accuracy(y, pred)
                if score>bestScore:
                    bestScore=score
                    bestCriter=criter
                    bestDepth=depth
                    bestLeaf=leaf
                    best_estimator=estimator
                print("Accuracy on validation set: {}".format(score))
print('{} {} {} {}'.format(bestCriter, bestDepth, bestLeaf, best_estimator))
base_learner = DecisionTree(criterion=bestCriter, max_depth=bestDepth, min_samples_leaf=bestLeaf, sample_feature=True)
rf = RandomForest(base_learner=base_learner, num_trees=best_estimator, min_features=2020)

rf.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, rf.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, rf.predict(X_test))))
# Out:
# 3 1 entropy 10
# Accuracy on validation set: 0.7574021012416428
# 3 1 entropy 20
# Accuracy on validation set: 0.7612225405921681
# 3 1 entropy 40
# Accuracy on validation set: 0.772683858643744
# 3 1 entropy 100
# Accuracy on validation set: 0.7736389684813754
# 3 1 ratioInfoGain 10
# Accuracy on validation set: 0.778414517669532
# 3 1 ratioInfoGain 20
# Accuracy on validation set: 0.7593123209169055
# 3 1 ratioInfoGain 40
# Accuracy on validation set: 0.7631327602674307
# 3 1 ratioInfoGain 100
# Accuracy on validation set: 0.7774594078319007
# 3 1 gini 10
# Accuracy on validation set: 0.7535816618911175
# 3 1 gini 20
# Accuracy on validation set: 0.7535816618911175
# 3 1 gini 40
# Accuracy on validation set: 0.7717287488061128
# 3 1 gini 100
# Accuracy on validation set: 0.7774594078319007
# 3 4 entropy 10
# Accuracy on validation set: 0.7621776504297995
# 3 4 entropy 20
# Accuracy on validation set: 0.7650429799426934
# 3 4 entropy 40
# Accuracy on validation set: 0.7870105062082139
# 3 4 entropy 100
# Accuracy on validation set: 0.7831900668576887
# 3 4 ratioInfoGain 10
# Accuracy on validation set: 0.7497612225405922
# 3 4 ratioInfoGain 20
# Accuracy on validation set: 0.7707736389684814
# 3 4 ratioInfoGain 40
# Accuracy on validation set: 0.775549188156638
# 3 4 ratioInfoGain 100
# Accuracy on validation set: 0.7717287488061128
# 3 4 gini 10
# Accuracy on validation set: 0.7516714422158548
# 3 4 gini 20
# Accuracy on validation set: 0.76981852913085
# 3 4 gini 40
# Accuracy on validation set: 0.7688634192932188
# 3 4 gini 100
# Accuracy on validation set: 0.7774594078319007
# 3 8 entropy 10
# Accuracy on validation set: 0.7659980897803247
# 3 8 entropy 20
# Accuracy on validation set: 0.7688634192932188
# 3 8 entropy 40
# Accuracy on validation set: 0.7793696275071633
# 3 8 entropy 100
# Accuracy on validation set: 0.7841451766953199
# 3 8 ratioInfoGain 10
# Accuracy on validation set: 0.7554918815663801
# 3 8 ratioInfoGain 20
# Accuracy on validation set: 0.7516714422158548
# 3 8 ratioInfoGain 40
# Accuracy on validation set: 0.7736389684813754
# 3 8 ratioInfoGain 100
# Accuracy on validation set: 0.76981852913085
# 3 8 gini 10
# Accuracy on validation set: 0.7411652340019103
# 3 8 gini 20
# Accuracy on validation set: 0.7765042979942693
# 3 8 gini 40
# Accuracy on validation set: 0.76981852913085
# 3 8 gini 100
# Accuracy on validation set: 0.7793696275071633
# 3 16 entropy 10
# Accuracy on validation set: 0.7564469914040115
# 3 16 entropy 20
# Accuracy on validation set: 0.7688634192932188
# 3 16 entropy 40
# Accuracy on validation set: 0.7631327602674307
# 3 16 entropy 100
# Accuracy on validation set: 0.775549188156638
# 3 16 ratioInfoGain 10
# Accuracy on validation set: 0.7526265520534862
# 3 16 ratioInfoGain 20
# Accuracy on validation set: 0.7507163323782235
# 3 16 ratioInfoGain 40
# Accuracy on validation set: 0.7774594078319007
# 3 16 ratioInfoGain 100
# Accuracy on validation set: 0.775549188156638
# 3 16 gini 10
# Accuracy on validation set: 0.7631327602674307
# 3 16 gini 20
# Accuracy on validation set: 0.7602674307545367
# 3 16 gini 40
# Accuracy on validation set: 0.7822349570200573
# 3 16 gini 100
# Accuracy on validation set: 0.775549188156638
# 3 32 entropy 10
# Accuracy on validation set: 0.7736389684813754
# 3 32 entropy 20
# Accuracy on validation set: 0.7602674307545367
# 3 32 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 3 32 entropy 100
# Accuracy on validation set: 0.7793696275071633
# 3 32 ratioInfoGain 10
# Accuracy on validation set: 0.7526265520534862
# 3 32 ratioInfoGain 20
# Accuracy on validation set: 0.7497612225405922
# 3 32 ratioInfoGain 40
# Accuracy on validation set: 0.7650429799426934
# 3 32 ratioInfoGain 100
# Accuracy on validation set: 0.778414517669532
# 3 32 gini 10
# Accuracy on validation set: 0.7736389684813754
# 3 32 gini 20
# Accuracy on validation set: 0.7717287488061128
# 3 32 gini 40
# Accuracy on validation set: 0.7679083094555874
# 3 32 gini 100
# Accuracy on validation set: 0.7765042979942693
# 3 64 entropy 10
# Accuracy on validation set: 0.7554918815663801
# 3 64 entropy 20
# Accuracy on validation set: 0.7612225405921681
# 3 64 entropy 40
# Accuracy on validation set: 0.775549188156638
# 3 64 entropy 100
# Accuracy on validation set: 0.7745940783190067
# 3 64 ratioInfoGain 10
# Accuracy on validation set: 0.7363896848137536
# 3 64 ratioInfoGain 20
# Accuracy on validation set: 0.7688634192932188
# 3 64 ratioInfoGain 40
# Accuracy on validation set: 0.7679083094555874
# 3 64 ratioInfoGain 100
# Accuracy on validation set: 0.7736389684813754
# 3 64 gini 10
# Accuracy on validation set: 0.7507163323782235
# 3 64 gini 20
# Accuracy on validation set: 0.7679083094555874
# 3 64 gini 40
# Accuracy on validation set: 0.7774594078319007
# 3 64 gini 100
# Accuracy on validation set: 0.7736389684813754
# 4 1 entropy 10
# Accuracy on validation set: 0.7879656160458453
# 4 1 entropy 20
# Accuracy on validation set: 0.7870105062082139
# 4 1 entropy 40
# Accuracy on validation set: 0.7870105062082139
# 4 1 entropy 100
# Accuracy on validation set: 0.7965616045845272
# 4 1 ratioInfoGain 10
# Accuracy on validation set: 0.7889207258834766
# 4 1 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 4 1 ratioInfoGain 40
# Accuracy on validation set: 0.7860553963705826
# 4 1 ratioInfoGain 100
# Accuracy on validation set: 0.7860553963705826
# 4 1 gini 10
# Accuracy on validation set: 0.7745940783190067
# 4 1 gini 20
# Accuracy on validation set: 0.778414517669532
# 4 1 gini 40
# Accuracy on validation set: 0.7860553963705826
# 4 1 gini 100
# Accuracy on validation set: 0.7831900668576887
# 4 4 entropy 10
# Accuracy on validation set: 0.7765042979942693
# 4 4 entropy 20
# Accuracy on validation set: 0.7793696275071633
# 4 4 entropy 40
# Accuracy on validation set: 0.789875835721108
# 4 4 entropy 100
# Accuracy on validation set: 0.789875835721108
# 4 4 ratioInfoGain 10
# Accuracy on validation set: 0.7803247373447947
# 4 4 ratioInfoGain 20
# Accuracy on validation set: 0.7803247373447947
# 4 4 ratioInfoGain 40
# Accuracy on validation set: 0.7812798471824259
# 4 4 ratioInfoGain 100
# Accuracy on validation set: 0.7831900668576887
# 4 4 gini 10
# Accuracy on validation set: 0.7717287488061128
# 4 4 gini 20
# Accuracy on validation set: 0.7879656160458453
# 4 4 gini 40
# Accuracy on validation set: 0.7812798471824259
# 4 4 gini 100
# Accuracy on validation set: 0.7917860553963706
# 4 8 entropy 10
# Accuracy on validation set: 0.7841451766953199
# 4 8 entropy 20
# Accuracy on validation set: 0.7736389684813754
# 4 8 entropy 40
# Accuracy on validation set: 0.7851002865329513
# 4 8 entropy 100
# Accuracy on validation set: 0.7803247373447947
# 4 8 ratioInfoGain 10
# Accuracy on validation set: 0.7765042979942693
# 4 8 ratioInfoGain 20
# Accuracy on validation set: 0.7717287488061128
# 4 8 ratioInfoGain 40
# Accuracy on validation set: 0.7879656160458453
# 4 8 ratioInfoGain 100
# Accuracy on validation set: 0.7812798471824259
# 4 8 gini 10
# Accuracy on validation set: 0.789875835721108
# 4 8 gini 20
# Accuracy on validation set: 0.775549188156638
# 4 8 gini 40
# Accuracy on validation set: 0.7851002865329513
# 4 8 gini 100
# Accuracy on validation set: 0.7841451766953199
# 4 16 entropy 10
# Accuracy on validation set: 0.7793696275071633
# 4 16 entropy 20
# Accuracy on validation set: 0.7841451766953199
# 4 16 entropy 40
# Accuracy on validation set: 0.7851002865329513
# 4 16 entropy 100
# Accuracy on validation set: 0.7841451766953199
# 4 16 ratioInfoGain 10
# Accuracy on validation set: 0.7707736389684814
# 4 16 ratioInfoGain 20
# Accuracy on validation set: 0.7707736389684814
# 4 16 ratioInfoGain 40
# Accuracy on validation set: 0.7908309455587392
# 4 16 ratioInfoGain 100
# Accuracy on validation set: 0.792741165234002
# 4 16 gini 10
# Accuracy on validation set: 0.7803247373447947
# 4 16 gini 20
# Accuracy on validation set: 0.7812798471824259
# 4 16 gini 40
# Accuracy on validation set: 0.7765042979942693
# 4 16 gini 100
# Accuracy on validation set: 0.7908309455587392
# 4 32 entropy 10
# Accuracy on validation set: 0.7917860553963706
# 4 32 entropy 20
# Accuracy on validation set: 0.7841451766953199
# 4 32 entropy 40
# Accuracy on validation set: 0.7793696275071633
# 4 32 entropy 100
# Accuracy on validation set: 0.7889207258834766
# 4 32 ratioInfoGain 10
# Accuracy on validation set: 0.7765042979942693
# 4 32 ratioInfoGain 20
# Accuracy on validation set: 0.789875835721108
# 4 32 ratioInfoGain 40
# Accuracy on validation set: 0.7908309455587392
# 4 32 ratioInfoGain 100
# Accuracy on validation set: 0.7841451766953199
# 4 32 gini 10
# Accuracy on validation set: 0.778414517669532
# 4 32 gini 20
# Accuracy on validation set: 0.7736389684813754
# 4 32 gini 40
# Accuracy on validation set: 0.7860553963705826
# 4 32 gini 100
# Accuracy on validation set: 0.789875835721108
# 4 64 entropy 10
# Accuracy on validation set: 0.7745940783190067
# 4 64 entropy 20
# Accuracy on validation set: 0.76981852913085
# 4 64 entropy 40
# Accuracy on validation set: 0.7851002865329513
# 4 64 entropy 100
# Accuracy on validation set: 0.792741165234002
# 4 64 ratioInfoGain 10
# Accuracy on validation set: 0.7936962750716332
# 4 64 ratioInfoGain 20
# Accuracy on validation set: 0.7774594078319007
# 4 64 ratioInfoGain 40
# Accuracy on validation set: 0.778414517669532
# 4 64 ratioInfoGain 100
# Accuracy on validation set: 0.7803247373447947
# 4 64 gini 10
# Accuracy on validation set: 0.7831900668576887
# 4 64 gini 20
# Accuracy on validation set: 0.7812798471824259
# 4 64 gini 40
# Accuracy on validation set: 0.7860553963705826
# 4 64 gini 100
# Accuracy on validation set: 0.7803247373447947
# 5 1 entropy 10
# Accuracy on validation set: 0.7870105062082139
# 5 1 entropy 20
# Accuracy on validation set: 0.7870105062082139
# 5 1 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 5 1 entropy 100
# Accuracy on validation set: 0.7908309455587392
# 5 1 ratioInfoGain 10
# Accuracy on validation set: 0.7822349570200573
# 5 1 ratioInfoGain 20
# Accuracy on validation set: 0.7870105062082139
# 5 1 ratioInfoGain 40
# Accuracy on validation set: 0.7917860553963706
# 5 1 ratioInfoGain 100
# Accuracy on validation set: 0.7917860553963706
# 5 1 gini 10
# Accuracy on validation set: 0.7841451766953199
# 5 1 gini 20
# Accuracy on validation set: 0.7812798471824259
# 5 1 gini 40
# Accuracy on validation set: 0.7831900668576887
# 5 1 gini 100
# Accuracy on validation set: 0.7889207258834766
# 5 4 entropy 10
# Accuracy on validation set: 0.7688634192932188
# 5 4 entropy 20
# Accuracy on validation set: 0.7717287488061128
# 5 4 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 5 4 entropy 100
# Accuracy on validation set: 0.7975167144221585
# 5 4 ratioInfoGain 10
# Accuracy on validation set: 0.8003820439350525
# 5 4 ratioInfoGain 20
# Accuracy on validation set: 0.7851002865329513
# 5 4 ratioInfoGain 40
# Accuracy on validation set: 0.7917860553963706
# 5 4 ratioInfoGain 100
# Accuracy on validation set: 0.7860553963705826
# 5 4 gini 10
# Accuracy on validation set: 0.7774594078319007
# 5 4 gini 20
# Accuracy on validation set: 0.778414517669532
# 5 4 gini 40
# Accuracy on validation set: 0.7851002865329513
# 5 4 gini 100
# Accuracy on validation set: 0.7908309455587392
# 5 8 entropy 10
# Accuracy on validation set: 0.7793696275071633
# 5 8 entropy 20
# Accuracy on validation set: 0.7793696275071633
# 5 8 entropy 40
# Accuracy on validation set: 0.7917860553963706
# 5 8 entropy 100
# Accuracy on validation set: 0.7851002865329513
# 5 8 ratioInfoGain 10
# Accuracy on validation set: 0.7793696275071633
# 5 8 ratioInfoGain 20
# Accuracy on validation set: 0.7793696275071633
# 5 8 ratioInfoGain 40
# Accuracy on validation set: 0.7889207258834766
# 5 8 ratioInfoGain 100
# Accuracy on validation set: 0.792741165234002
# 5 8 gini 10
# Accuracy on validation set: 0.7793696275071633
# 5 8 gini 20
# Accuracy on validation set: 0.7851002865329513
# 5 8 gini 40
# Accuracy on validation set: 0.7860553963705826
# 5 8 gini 100
# Accuracy on validation set: 0.7860553963705826
# 5 16 entropy 10
# Accuracy on validation set: 0.76981852913085
# 5 16 entropy 20
# Accuracy on validation set: 0.7870105062082139
# 5 16 entropy 40
# Accuracy on validation set: 0.789875835721108
# 5 16 entropy 100
# Accuracy on validation set: 0.7908309455587392
# 5 16 ratioInfoGain 10
# Accuracy on validation set: 0.7822349570200573
# 5 16 ratioInfoGain 20
# Accuracy on validation set: 0.7889207258834766
# 5 16 ratioInfoGain 40
# Accuracy on validation set: 0.7936962750716332
# 5 16 ratioInfoGain 100
# Accuracy on validation set: 0.789875835721108
# 5 16 gini 10
# Accuracy on validation set: 0.7793696275071633
# 5 16 gini 20
# Accuracy on validation set: 0.7908309455587392
# 5 16 gini 40
# Accuracy on validation set: 0.7870105062082139
# 5 16 gini 100
# Accuracy on validation set: 0.789875835721108
# 5 32 entropy 10
# Accuracy on validation set: 0.7831900668576887
# 5 32 entropy 20
# Accuracy on validation set: 0.7860553963705826
# 5 32 entropy 40
# Accuracy on validation set: 0.7946513849092646
# 5 32 entropy 100
# Accuracy on validation set: 0.7851002865329513
# 5 32 ratioInfoGain 10
# Accuracy on validation set: 0.7736389684813754
# 5 32 ratioInfoGain 20
# Accuracy on validation set: 0.7793696275071633
# 5 32 ratioInfoGain 40
# Accuracy on validation set: 0.7936962750716332
# 5 32 ratioInfoGain 100
# Accuracy on validation set: 0.7908309455587392
# 5 32 gini 10
# Accuracy on validation set: 0.7879656160458453
# 5 32 gini 20
# Accuracy on validation set: 0.7908309455587392
# 5 32 gini 40
# Accuracy on validation set: 0.7822349570200573
# 5 32 gini 100
# Accuracy on validation set: 0.792741165234002
# 5 64 entropy 10
# Accuracy on validation set: 0.778414517669532
# 5 64 entropy 20
# Accuracy on validation set: 0.7765042979942693
# 5 64 entropy 40
# Accuracy on validation set: 0.7831900668576887
# 5 64 entropy 100
# Accuracy on validation set: 0.7879656160458453
# 5 64 ratioInfoGain 10
# Accuracy on validation set: 0.7745940783190067
# 5 64 ratioInfoGain 20
# Accuracy on validation set: 0.772683858643744
# 5 64 ratioInfoGain 40
# Accuracy on validation set: 0.7822349570200573
# 5 64 ratioInfoGain 100
# Accuracy on validation set: 0.7822349570200573
# 5 64 gini 10
# Accuracy on validation set: 0.766953199617956
# 5 64 gini 20
# Accuracy on validation set: 0.7851002865329513
# 5 64 gini 40
# Accuracy on validation set: 0.7803247373447947
# 5 64 gini 100
# Accuracy on validation set: 0.7908309455587392
# 6 1 entropy 10
# Accuracy on validation set: 0.7831900668576887
# 6 1 entropy 20
# Accuracy on validation set: 0.7889207258834766
# 6 1 entropy 40
# Accuracy on validation set: 0.7822349570200573
# 6 1 entropy 100
# Accuracy on validation set: 0.7851002865329513
# 6 1 ratioInfoGain 10
# Accuracy on validation set: 0.7812798471824259
# 6 1 ratioInfoGain 20
# Accuracy on validation set: 0.7812798471824259
# 6 1 ratioInfoGain 40
# Accuracy on validation set: 0.7889207258834766
# 6 1 ratioInfoGain 100
# Accuracy on validation set: 0.7822349570200573
# 6 1 gini 10
# Accuracy on validation set: 0.7812798471824259
# 6 1 gini 20
# Accuracy on validation set: 0.778414517669532
# 6 1 gini 40
# Accuracy on validation set: 0.7908309455587392
# 6 1 gini 100
# Accuracy on validation set: 0.7831900668576887
# 6 4 entropy 10
# Accuracy on validation set: 0.7831900668576887
# 6 4 entropy 20
# Accuracy on validation set: 0.7860553963705826
# 6 4 entropy 40
# Accuracy on validation set: 0.7879656160458453
# 6 4 entropy 100
# Accuracy on validation set: 0.7841451766953199
# 6 4 ratioInfoGain 10
# Accuracy on validation set: 0.7851002865329513
# 6 4 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 6 4 ratioInfoGain 40
# Accuracy on validation set: 0.778414517669532
# 6 4 ratioInfoGain 100
# Accuracy on validation set: 0.7889207258834766
# 6 4 gini 10
# Accuracy on validation set: 0.7860553963705826
# 6 4 gini 20
# Accuracy on validation set: 0.778414517669532
# 6 4 gini 40
# Accuracy on validation set: 0.7841451766953199
# 6 4 gini 100
# Accuracy on validation set: 0.7870105062082139
# 6 8 entropy 10
# Accuracy on validation set: 0.7803247373447947
# 6 8 entropy 20
# Accuracy on validation set: 0.7812798471824259
# 6 8 entropy 40
# Accuracy on validation set: 0.7946513849092646
# 6 8 entropy 100
# Accuracy on validation set: 0.7851002865329513
# 6 8 ratioInfoGain 10
# Accuracy on validation set: 0.7870105062082139
# 6 8 ratioInfoGain 20
# Accuracy on validation set: 0.7851002865329513
# 6 8 ratioInfoGain 40
# Accuracy on validation set: 0.792741165234002
# 6 8 ratioInfoGain 100
# Accuracy on validation set: 0.7908309455587392
# 6 8 gini 10
# Accuracy on validation set: 0.7822349570200573
# 6 8 gini 20
# Accuracy on validation set: 0.7774594078319007
# 6 8 gini 40
# Accuracy on validation set: 0.7889207258834766
# 6 8 gini 100
# Accuracy on validation set: 0.7879656160458453
# 6 16 entropy 10
# Accuracy on validation set: 0.7831900668576887
# 6 16 entropy 20
# Accuracy on validation set: 0.7879656160458453
# 6 16 entropy 40
# Accuracy on validation set: 0.7803247373447947
# 6 16 entropy 100
# Accuracy on validation set: 0.7831900668576887
# 6 16 ratioInfoGain 10
# Accuracy on validation set: 0.7793696275071633
# 6 16 ratioInfoGain 20
# Accuracy on validation set: 0.7765042979942693
# 6 16 ratioInfoGain 40
# Accuracy on validation set: 0.8013371537726839
# 6 16 ratioInfoGain 100
# Accuracy on validation set: 0.789875835721108
# 6 16 gini 10
# Accuracy on validation set: 0.7889207258834766
# 6 16 gini 20
# Accuracy on validation set: 0.7812798471824259
# 6 16 gini 40
# Accuracy on validation set: 0.7822349570200573
# 6 16 gini 100
# Accuracy on validation set: 0.7908309455587392
# 6 32 entropy 10
# Accuracy on validation set: 0.775549188156638
# 6 32 entropy 20
# Accuracy on validation set: 0.7812798471824259
# 6 32 entropy 40
# Accuracy on validation set: 0.7956064947468959
# 6 32 entropy 100
# Accuracy on validation set: 0.7917860553963706
# 6 32 ratioInfoGain 10
# Accuracy on validation set: 0.7793696275071633
# 6 32 ratioInfoGain 20
# Accuracy on validation set: 0.772683858643744
# 6 32 ratioInfoGain 40
# Accuracy on validation set: 0.7917860553963706
# 6 32 ratioInfoGain 100
# Accuracy on validation set: 0.789875835721108
# 6 32 gini 10
# Accuracy on validation set: 0.7908309455587392
# 6 32 gini 20
# Accuracy on validation set: 0.7860553963705826
# 6 32 gini 40
# Accuracy on validation set: 0.7870105062082139
# 6 32 gini 100
# Accuracy on validation set: 0.7917860553963706
# 6 64 entropy 10
# Accuracy on validation set: 0.778414517669532
# 6 64 entropy 20
# Accuracy on validation set: 0.7745940783190067
# 6 64 entropy 40
# Accuracy on validation set: 0.7870105062082139
# 6 64 entropy 100
# Accuracy on validation set: 0.7831900668576887
# 6 64 ratioInfoGain 10
# Accuracy on validation set: 0.7765042979942693
# 6 64 ratioInfoGain 20
# Accuracy on validation set: 0.7745940783190067
# 6 64 ratioInfoGain 40
# Accuracy on validation set: 0.7831900668576887
# 6 64 ratioInfoGain 100
# Accuracy on validation set: 0.7889207258834766
# 6 64 gini 10
# Accuracy on validation set: 0.7765042979942693
# 6 64 gini 20
# Accuracy on validation set: 0.7793696275071633
# 6 64 gini 40
# Accuracy on validation set: 0.7841451766953199
# 6 64 gini 100
# Accuracy on validation set: 0.7851002865329513
# 7 1 entropy 10
# Accuracy on validation set: 0.7879656160458453
# 7 1 entropy 20
# Accuracy on validation set: 0.7879656160458453
# 7 1 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 7 1 entropy 100
# Accuracy on validation set: 0.7803247373447947
# 7 1 ratioInfoGain 10
# Accuracy on validation set: 0.7765042979942693
# 7 1 ratioInfoGain 20
# Accuracy on validation set: 0.7831900668576887
# 7 1 ratioInfoGain 40
# Accuracy on validation set: 0.7774594078319007
# 7 1 ratioInfoGain 100
# Accuracy on validation set: 0.7870105062082139
# 7 1 gini 10
# Accuracy on validation set: 0.7812798471824259
# 7 1 gini 20
# Accuracy on validation set: 0.7908309455587392
# 7 1 gini 40
# Accuracy on validation set: 0.7803247373447947
# 7 1 gini 100
# Accuracy on validation set: 0.778414517669532
# 7 4 entropy 10
# Accuracy on validation set: 0.7870105062082139
# 7 4 entropy 20
# Accuracy on validation set: 0.7812798471824259
# 7 4 entropy 40
# Accuracy on validation set: 0.778414517669532
# 7 4 entropy 100
# Accuracy on validation set: 0.7822349570200573
# 7 4 ratioInfoGain 10
# Accuracy on validation set: 0.7841451766953199
# 7 4 ratioInfoGain 20
# Accuracy on validation set: 0.7851002865329513
# 7 4 ratioInfoGain 40
# Accuracy on validation set: 0.7917860553963706
# 7 4 ratioInfoGain 100
# Accuracy on validation set: 0.7851002865329513
# 7 4 gini 10
# Accuracy on validation set: 0.7851002865329513
# 7 4 gini 20
# Accuracy on validation set: 0.7822349570200573
# 7 4 gini 40
# Accuracy on validation set: 0.7889207258834766
# 7 4 gini 100
# Accuracy on validation set: 0.7822349570200573
# 7 8 entropy 10
# Accuracy on validation set: 0.7889207258834766
# 7 8 entropy 20
# Accuracy on validation set: 0.7803247373447947
# 7 8 entropy 40
# Accuracy on validation set: 0.7841451766953199
# 7 8 entropy 100
# Accuracy on validation set: 0.7822349570200573
# 7 8 ratioInfoGain 10
# Accuracy on validation set: 0.7831900668576887
# 7 8 ratioInfoGain 20
# Accuracy on validation set: 0.7803247373447947
# 7 8 ratioInfoGain 40
# Accuracy on validation set: 0.7841451766953199
# 7 8 ratioInfoGain 100
# Accuracy on validation set: 0.789875835721108
# 7 8 gini 10
# Accuracy on validation set: 0.7736389684813754
# 7 8 gini 20
# Accuracy on validation set: 0.778414517669532
# 7 8 gini 40
# Accuracy on validation set: 0.7831900668576887
# 7 8 gini 100
# Accuracy on validation set: 0.7812798471824259
# 7 16 entropy 10
# Accuracy on validation set: 0.7793696275071633
# 7 16 entropy 20
# Accuracy on validation set: 0.7822349570200573
# 7 16 entropy 40
# Accuracy on validation set: 0.792741165234002
# 7 16 entropy 100
# Accuracy on validation set: 0.7870105062082139
# 7 16 ratioInfoGain 10
# Accuracy on validation set: 0.7879656160458453
# 7 16 ratioInfoGain 20
# Accuracy on validation set: 0.792741165234002
# 7 16 ratioInfoGain 40
# Accuracy on validation set: 0.7879656160458453
# 7 16 ratioInfoGain 100
# Accuracy on validation set: 0.7879656160458453
# 7 16 gini 10
# Accuracy on validation set: 0.7908309455587392
# 7 16 gini 20
# Accuracy on validation set: 0.7860553963705826
# 7 16 gini 40
# Accuracy on validation set: 0.789875835721108
# 7 16 gini 100
# Accuracy on validation set: 0.7841451766953199
# 7 32 entropy 10
# Accuracy on validation set: 0.7679083094555874
# 7 32 entropy 20
# Accuracy on validation set: 0.7841451766953199
# 7 32 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 7 32 entropy 100
# Accuracy on validation set: 0.7870105062082139
# 7 32 ratioInfoGain 10
# Accuracy on validation set: 0.7745940783190067
# 7 32 ratioInfoGain 20
# Accuracy on validation set: 0.7879656160458453
# 7 32 ratioInfoGain 40
# Accuracy on validation set: 0.792741165234002
# 7 32 ratioInfoGain 100
# Accuracy on validation set: 0.7917860553963706
# 7 32 gini 10
# Accuracy on validation set: 0.7765042979942693
# 7 32 gini 20
# Accuracy on validation set: 0.7793696275071633
# 7 32 gini 40
# Accuracy on validation set: 0.7803247373447947
# 7 32 gini 100
# Accuracy on validation set: 0.7870105062082139
# 7 64 entropy 10
# Accuracy on validation set: 0.7803247373447947
# 7 64 entropy 20
# Accuracy on validation set: 0.7765042979942693
# 7 64 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 7 64 entropy 100
# Accuracy on validation set: 0.7831900668576887
# 7 64 ratioInfoGain 10
# Accuracy on validation set: 0.7793696275071633
# 7 64 ratioInfoGain 20
# Accuracy on validation set: 0.7803247373447947
# 7 64 ratioInfoGain 40
# Accuracy on validation set: 0.7851002865329513
# 7 64 ratioInfoGain 100
# Accuracy on validation set: 0.7917860553963706
# 7 64 gini 10
# Accuracy on validation set: 0.7812798471824259
# 7 64 gini 20
# Accuracy on validation set: 0.7831900668576887
# 7 64 gini 40
# Accuracy on validation set: 0.7851002865329513
# 7 64 gini 100
# Accuracy on validation set: 0.7860553963705826
# 8 1 entropy 10
# Accuracy on validation set: 0.7793696275071633
# 8 1 entropy 20
# Accuracy on validation set: 0.7889207258834766
# 8 1 entropy 40
# Accuracy on validation set: 0.7879656160458453
# 8 1 entropy 100
# Accuracy on validation set: 0.7851002865329513
# 8 1 ratioInfoGain 10
# Accuracy on validation set: 0.778414517669532
# 8 1 ratioInfoGain 20
# Accuracy on validation set: 0.7822349570200573
# 8 1 ratioInfoGain 40
# Accuracy on validation set: 0.7889207258834766
# 8 1 ratioInfoGain 100
# Accuracy on validation set: 0.7831900668576887
# 8 1 gini 10
# Accuracy on validation set: 0.7765042979942693
# 8 1 gini 20
# Accuracy on validation set: 0.7803247373447947
# 8 1 gini 40
# Accuracy on validation set: 0.778414517669532
# 8 1 gini 100
# Accuracy on validation set: 0.7822349570200573
# 8 4 entropy 10
# Accuracy on validation set: 0.7879656160458453
# 8 4 entropy 20
# Accuracy on validation set: 0.7946513849092646
# 8 4 entropy 40
# Accuracy on validation set: 0.7822349570200573
# 8 4 entropy 100
# Accuracy on validation set: 0.7879656160458453
# 8 4 ratioInfoGain 10
# Accuracy on validation set: 0.7879656160458453
# 8 4 ratioInfoGain 20
# Accuracy on validation set: 0.7879656160458453
# 8 4 ratioInfoGain 40
# Accuracy on validation set: 0.7889207258834766
# 8 4 ratioInfoGain 100
# Accuracy on validation set: 0.7879656160458453
# 8 4 gini 10
# Accuracy on validation set: 0.7860553963705826
# 8 4 gini 20
# Accuracy on validation set: 0.7812798471824259
# 8 4 gini 40
# Accuracy on validation set: 0.7851002865329513
# 8 4 gini 100
# Accuracy on validation set: 0.7831900668576887
# 8 8 entropy 10
# Accuracy on validation set: 0.7793696275071633
# 8 8 entropy 20
# Accuracy on validation set: 0.7956064947468959
# 8 8 entropy 40
# Accuracy on validation set: 0.7793696275071633
# 8 8 entropy 100
# Accuracy on validation set: 0.7860553963705826
# 8 8 ratioInfoGain 10
# Accuracy on validation set: 0.778414517669532
# 8 8 ratioInfoGain 20
# Accuracy on validation set: 0.792741165234002
# 8 8 ratioInfoGain 40
# Accuracy on validation set: 0.7831900668576887
# 8 8 ratioInfoGain 100
# Accuracy on validation set: 0.7860553963705826
# 8 8 gini 10
# Accuracy on validation set: 0.7860553963705826
# 8 8 gini 20
# Accuracy on validation set: 0.7889207258834766
# 8 8 gini 40
# Accuracy on validation set: 0.7793696275071633
# 8 8 gini 100
# Accuracy on validation set: 0.7851002865329513
# 8 16 entropy 10
# Accuracy on validation set: 0.7793696275071633
# 8 16 entropy 20
# Accuracy on validation set: 0.7841451766953199
# 8 16 entropy 40
# Accuracy on validation set: 0.7860553963705826
# 8 16 entropy 100
# Accuracy on validation set: 0.7908309455587392
# 8 16 ratioInfoGain 10
# Accuracy on validation set: 0.7917860553963706
# 8 16 ratioInfoGain 20
# Accuracy on validation set: 0.7851002865329513
# 8 16 ratioInfoGain 40
# Accuracy on validation set: 0.7936962750716332
# 8 16 ratioInfoGain 100
# Accuracy on validation set: 0.7879656160458453
# 8 16 gini 10
# Accuracy on validation set: 0.7812798471824259
# 8 16 gini 20
# Accuracy on validation set: 0.7812798471824259
# 8 16 gini 40
# Accuracy on validation set: 0.7870105062082139
# 8 16 gini 100
# Accuracy on validation set: 0.7889207258834766
# 8 32 entropy 10
# Accuracy on validation set: 0.7831900668576887
# 8 32 entropy 20
# Accuracy on validation set: 0.7870105062082139
# 8 32 entropy 40
# Accuracy on validation set: 0.7870105062082139
# 8 32 entropy 100
# Accuracy on validation set: 0.789875835721108
# 8 32 ratioInfoGain 10
# Accuracy on validation set: 0.775549188156638
# 8 32 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 8 32 ratioInfoGain 40
# Accuracy on validation set: 0.7889207258834766
# 8 32 ratioInfoGain 100
# Accuracy on validation set: 0.7975167144221585
# 8 32 gini 10
# Accuracy on validation set: 0.7822349570200573
# 8 32 gini 20
# Accuracy on validation set: 0.7879656160458453
# 8 32 gini 40
# Accuracy on validation set: 0.7870105062082139
# 8 32 gini 100
# Accuracy on validation set: 0.7917860553963706
# 8 64 entropy 10
# Accuracy on validation set: 0.772683858643744
# 8 64 entropy 20
# Accuracy on validation set: 0.7841451766953199
# 8 64 entropy 40
# Accuracy on validation set: 0.7841451766953199
# 8 64 entropy 100
# Accuracy on validation set: 0.7908309455587392
# 8 64 ratioInfoGain 10
# Accuracy on validation set: 0.7765042979942693
# 8 64 ratioInfoGain 20
# Accuracy on validation set: 0.7736389684813754
# 8 64 ratioInfoGain 40
# Accuracy on validation set: 0.7870105062082139
# 8 64 ratioInfoGain 100
# Accuracy on validation set: 0.7860553963705826
# 8 64 gini 10
# Accuracy on validation set: 0.766953199617956
# 8 64 gini 20
# Accuracy on validation set: 0.7822349570200573
# 8 64 gini 40
# Accuracy on validation set: 0.7822349570200573
# 8 64 gini 100
# Accuracy on validation set: 0.789875835721108
# ratioInfoGain 6 16 40
# Accuracy on train set: 0.8328557784145176
# Accuracy on test set: 0.8206106870229007

# %%
# report the accuracy on test set

criters=['entropy', 'ratioInfoGain','gini']
depths=[3, 4, 5, 6, 7, 8]
leaves=[1, 4, 8, 16, 32, 64]
estimators=[10, 20, 40, 100]
bestCriter=criters[0]
bestDepth=depths[0]
bestLeaf=leaves[0]
best_estimator=estimators[0]
bestScore=0.0

for depth in depths:
    for leaf in leaves:
        for criter in criters:
            for estimator in estimators:
                print('{} {} {} {}'.format(depth, leaf, criter, estimator))
                base_learner = DecisionTree(criterion=criter, max_depth=depth, min_samples_leaf=leaf, sample_feature=True)
                rf = RandomForest(base_learner=base_learner, num_trees=estimator, min_features=2020)
                rf.fit(X, y)
                score=accuracy(y_test, rf.predict(X_test))
                if score>bestScore:
                    bestScore=score
                    bestCriter=criter
                    bestDepth=depth
                    bestLeaf=leaf
                    best_estimator=estimator
                print("Accuracy on test set: {}".format(score))

print('{} {} {} {}'.format(bestCriter, bestDepth, bestLeaf, best_estimator))
base_learner = DecisionTree(criterion=bestCriter, max_depth=bestDepth, min_samples_leaf=bestLeaf, sample_feature=True)
rf = RandomForest(base_learner=base_learner, num_trees=best_estimator, min_features=2020)

rf.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, rf.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, rf.predict(X_test))))
# Out:
# 3 1 entropy 10
# Accuracy on test set: 0.732824427480916
# 3 1 entropy 20
# Accuracy on test set: 0.7595419847328244
# 3 1 entropy 40
# Accuracy on test set: 0.7748091603053435
# 3 1 entropy 100
# Accuracy on test set: 0.7977099236641222
# 3 1 ratioInfoGain 10
# Accuracy on test set: 0.7633587786259542
# 3 1 ratioInfoGain 20
# Accuracy on test set: 0.7938931297709924
# 3 1 ratioInfoGain 40
# Accuracy on test set: 0.7862595419847328
# 3 1 ratioInfoGain 100
# Accuracy on test set: 0.7786259541984732
# 3 1 gini 10
# Accuracy on test set: 0.7709923664122137
# 3 1 gini 20
# Accuracy on test set: 0.7748091603053435
# 3 1 gini 40
# Accuracy on test set: 0.7748091603053435
# 3 1 gini 100
# Accuracy on test set: 0.7633587786259542
# 3 4 entropy 10
# Accuracy on test set: 0.7404580152671756
# 3 4 entropy 20
# Accuracy on test set: 0.767175572519084
# 3 4 entropy 40
# Accuracy on test set: 0.7709923664122137
# 3 4 entropy 100
# Accuracy on test set: 0.7977099236641222
# 3 4 ratioInfoGain 10
# Accuracy on test set: 0.7519083969465649
# 3 4 ratioInfoGain 20
# Accuracy on test set: 0.7709923664122137
# 3 4 ratioInfoGain 40
# Accuracy on test set: 0.7748091603053435
# 3 4 ratioInfoGain 100
# Accuracy on test set: 0.7938931297709924
# 3 4 gini 10
# Accuracy on test set: 0.7709923664122137
# 3 4 gini 20
# Accuracy on test set: 0.7977099236641222
# 3 4 gini 40
# Accuracy on test set: 0.7862595419847328
# 3 4 gini 100
# Accuracy on test set: 0.7862595419847328
# 3 8 entropy 10
# Accuracy on test set: 0.7595419847328244
# 3 8 entropy 20
# Accuracy on test set: 0.7938931297709924
# 3 8 entropy 40
# Accuracy on test set: 0.7709923664122137
# 3 8 entropy 100
# Accuracy on test set: 0.7938931297709924
# 3 8 ratioInfoGain 10
# Accuracy on test set: 0.7519083969465649
# 3 8 ratioInfoGain 20
# Accuracy on test set: 0.7595419847328244
# 3 8 ratioInfoGain 40
# Accuracy on test set: 0.7748091603053435
# 3 8 ratioInfoGain 100
# Accuracy on test set: 0.7938931297709924
# 3 8 gini 10
# Accuracy on test set: 0.7213740458015268
# 3 8 gini 20
# Accuracy on test set: 0.7633587786259542
# 3 8 gini 40
# Accuracy on test set: 0.7900763358778626
# 3 8 gini 100
# Accuracy on test set: 0.7748091603053435
# 3 16 entropy 10
# Accuracy on test set: 0.767175572519084
# 3 16 entropy 20
# Accuracy on test set: 0.7709923664122137
# 3 16 entropy 40
# Accuracy on test set: 0.7748091603053435
# 3 16 entropy 100
# Accuracy on test set: 0.7977099236641222
# 3 16 ratioInfoGain 10
# Accuracy on test set: 0.7442748091603053
# 3 16 ratioInfoGain 20
# Accuracy on test set: 0.7633587786259542
# 3 16 ratioInfoGain 40
# Accuracy on test set: 0.7977099236641222
# 3 16 ratioInfoGain 100
# Accuracy on test set: 0.7748091603053435
# 3 16 gini 10
# Accuracy on test set: 0.7824427480916031
# 3 16 gini 20
# Accuracy on test set: 0.8053435114503816
# 3 16 gini 40
# Accuracy on test set: 0.7748091603053435
# 3 16 gini 100
# Accuracy on test set: 0.7938931297709924
# 3 32 entropy 10
# Accuracy on test set: 0.7786259541984732
# 3 32 entropy 20
# Accuracy on test set: 0.7709923664122137
# 3 32 entropy 40
# Accuracy on test set: 0.8053435114503816
# 3 32 entropy 100
# Accuracy on test set: 0.7748091603053435
# 3 32 ratioInfoGain 10
# Accuracy on test set: 0.8053435114503816
# 3 32 ratioInfoGain 20
# Accuracy on test set: 0.7633587786259542
# 3 32 ratioInfoGain 40
# Accuracy on test set: 0.7977099236641222
# 3 32 ratioInfoGain 100
# Accuracy on test set: 0.7748091603053435
# 3 32 gini 10
# Accuracy on test set: 0.7938931297709924
# 3 32 gini 20
# Accuracy on test set: 0.7824427480916031
# 3 32 gini 40
# Accuracy on test set: 0.7938931297709924
# 3 32 gini 100
# Accuracy on test set: 0.767175572519084
# 3 64 entropy 10
# Accuracy on test set: 0.7824427480916031
# 3 64 entropy 20
# Accuracy on test set: 0.767175572519084
# 3 64 entropy 40
# Accuracy on test set: 0.7862595419847328
# 3 64 entropy 100
# Accuracy on test set: 0.7977099236641222
# 3 64 ratioInfoGain 10
# Accuracy on test set: 0.7290076335877863
# 3 64 ratioInfoGain 20
# Accuracy on test set: 0.7748091603053435
# 3 64 ratioInfoGain 40
# Accuracy on test set: 0.7748091603053435
# 3 64 ratioInfoGain 100
# Accuracy on test set: 0.7938931297709924
# 3 64 gini 10
# Accuracy on test set: 0.7366412213740458
# 3 64 gini 20
# Accuracy on test set: 0.7748091603053435
# 3 64 gini 40
# Accuracy on test set: 0.7748091603053435
# 3 64 gini 100
# Accuracy on test set: 0.7938931297709924
# 4 1 entropy 10
# Accuracy on test set: 0.7748091603053435
# 4 1 entropy 20
# Accuracy on test set: 0.8091603053435115
# 4 1 entropy 40
# Accuracy on test set: 0.8015267175572519
# 4 1 entropy 100
# Accuracy on test set: 0.8015267175572519
# 4 1 ratioInfoGain 10
# Accuracy on test set: 0.7938931297709924
# 4 1 ratioInfoGain 20
# Accuracy on test set: 0.7709923664122137
# 4 1 ratioInfoGain 40
# Accuracy on test set: 0.8091603053435115
# 4 1 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 4 1 gini 10
# Accuracy on test set: 0.7709923664122137
# 4 1 gini 20
# Accuracy on test set: 0.8091603053435115
# 4 1 gini 40
# Accuracy on test set: 0.7977099236641222
# 4 1 gini 100
# Accuracy on test set: 0.8206106870229007
# 4 4 entropy 10
# Accuracy on test set: 0.8129770992366412
# 4 4 entropy 20
# Accuracy on test set: 0.8129770992366412
# 4 4 entropy 40
# Accuracy on test set: 0.7977099236641222
# 4 4 entropy 100
# Accuracy on test set: 0.8129770992366412
# 4 4 ratioInfoGain 10
# Accuracy on test set: 0.7595419847328244
# 4 4 ratioInfoGain 20
# Accuracy on test set: 0.7977099236641222
# 4 4 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 4 4 ratioInfoGain 100
# Accuracy on test set: 0.8129770992366412
# 4 4 gini 10
# Accuracy on test set: 0.7900763358778626
# 4 4 gini 20
# Accuracy on test set: 0.7977099236641222
# 4 4 gini 40
# Accuracy on test set: 0.7977099236641222
# 4 4 gini 100
# Accuracy on test set: 0.8091603053435115
# 4 8 entropy 10
# Accuracy on test set: 0.8129770992366412
# 4 8 entropy 20
# Accuracy on test set: 0.8015267175572519
# 4 8 entropy 40
# Accuracy on test set: 0.8206106870229007
# 4 8 entropy 100
# Accuracy on test set: 0.8091603053435115
# 4 8 ratioInfoGain 10
# Accuracy on test set: 0.7748091603053435
# 4 8 ratioInfoGain 20
# Accuracy on test set: 0.7977099236641222
# 4 8 ratioInfoGain 40
# Accuracy on test set: 0.7938931297709924
# 4 8 ratioInfoGain 100
# Accuracy on test set: 0.8091603053435115
# 4 8 gini 10
# Accuracy on test set: 0.7709923664122137
# 4 8 gini 20
# Accuracy on test set: 0.7900763358778626
# 4 8 gini 40
# Accuracy on test set: 0.8129770992366412
# 4 8 gini 100
# Accuracy on test set: 0.8129770992366412
# 4 16 entropy 10
# Accuracy on test set: 0.7977099236641222
# 4 16 entropy 20
# Accuracy on test set: 0.8091603053435115
# 4 16 entropy 40
# Accuracy on test set: 0.8015267175572519
# 4 16 entropy 100
# Accuracy on test set: 0.8015267175572519
# 4 16 ratioInfoGain 10
# Accuracy on test set: 0.7824427480916031
# 4 16 ratioInfoGain 20
# Accuracy on test set: 0.7709923664122137
# 4 16 ratioInfoGain 40
# Accuracy on test set: 0.8091603053435115
# 4 16 ratioInfoGain 100
# Accuracy on test set: 0.8129770992366412
# 4 16 gini 10
# Accuracy on test set: 0.8091603053435115
# 4 16 gini 20
# Accuracy on test set: 0.8244274809160306
# 4 16 gini 40
# Accuracy on test set: 0.8053435114503816
# 4 16 gini 100
# Accuracy on test set: 0.8282442748091603
# 4 32 entropy 10
# Accuracy on test set: 0.7900763358778626
# 4 32 entropy 20
# Accuracy on test set: 0.8015267175572519
# 4 32 entropy 40
# Accuracy on test set: 0.7977099236641222
# 4 32 entropy 100
# Accuracy on test set: 0.8244274809160306
# 4 32 ratioInfoGain 10
# Accuracy on test set: 0.7595419847328244
# 4 32 ratioInfoGain 20
# Accuracy on test set: 0.8206106870229007
# 4 32 ratioInfoGain 40
# Accuracy on test set: 0.8091603053435115
# 4 32 ratioInfoGain 100
# Accuracy on test set: 0.7977099236641222
# 4 32 gini 10
# Accuracy on test set: 0.816793893129771
# 4 32 gini 20
# Accuracy on test set: 0.7938931297709924
# 4 32 gini 40
# Accuracy on test set: 0.8091603053435115
# 4 32 gini 100
# Accuracy on test set: 0.8091603053435115
# 4 64 entropy 10
# Accuracy on test set: 0.7748091603053435
# 4 64 entropy 20
# Accuracy on test set: 0.8053435114503816
# 4 64 entropy 40
# Accuracy on test set: 0.7900763358778626
# 4 64 entropy 100
# Accuracy on test set: 0.8091603053435115
# 4 64 ratioInfoGain 10
# Accuracy on test set: 0.8091603053435115
# 4 64 ratioInfoGain 20
# Accuracy on test set: 0.7862595419847328
# 4 64 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 4 64 ratioInfoGain 100
# Accuracy on test set: 0.8129770992366412
# 4 64 gini 10
# Accuracy on test set: 0.8053435114503816
# 4 64 gini 20
# Accuracy on test set: 0.7786259541984732
# 4 64 gini 40
# Accuracy on test set: 0.7977099236641222
# 4 64 gini 100
# Accuracy on test set: 0.7862595419847328
# 5 1 entropy 10
# Accuracy on test set: 0.816793893129771
# 5 1 entropy 20
# Accuracy on test set: 0.8129770992366412
# 5 1 entropy 40
# Accuracy on test set: 0.8206106870229007
# 5 1 entropy 100
# Accuracy on test set: 0.8129770992366412
# 5 1 ratioInfoGain 10
# Accuracy on test set: 0.8129770992366412
# 5 1 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 5 1 ratioInfoGain 40
# Accuracy on test set: 0.8320610687022901
# 5 1 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 5 1 gini 10
# Accuracy on test set: 0.8206106870229007
# 5 1 gini 20
# Accuracy on test set: 0.8015267175572519
# 5 1 gini 40
# Accuracy on test set: 0.8091603053435115
# 5 1 gini 100
# Accuracy on test set: 0.8129770992366412
# 5 4 entropy 10
# Accuracy on test set: 0.8320610687022901
# 5 4 entropy 20
# Accuracy on test set: 0.8015267175572519
# 5 4 entropy 40
# Accuracy on test set: 0.816793893129771
# 5 4 entropy 100
# Accuracy on test set: 0.8206106870229007
# 5 4 ratioInfoGain 10
# Accuracy on test set: 0.816793893129771
# 5 4 ratioInfoGain 20
# Accuracy on test set: 0.8282442748091603
# 5 4 ratioInfoGain 40
# Accuracy on test set: 0.8282442748091603
# 5 4 ratioInfoGain 100
# Accuracy on test set: 0.8282442748091603
# 5 4 gini 10
# Accuracy on test set: 0.7938931297709924
# 5 4 gini 20
# Accuracy on test set: 0.8091603053435115
# 5 4 gini 40
# Accuracy on test set: 0.8015267175572519
# 5 4 gini 100
# Accuracy on test set: 0.8206106870229007
# 5 8 entropy 10
# Accuracy on test set: 0.8244274809160306
# 5 8 entropy 20
# Accuracy on test set: 0.7938931297709924
# 5 8 entropy 40
# Accuracy on test set: 0.8206106870229007
# 5 8 entropy 100
# Accuracy on test set: 0.8129770992366412
# 5 8 ratioInfoGain 10
# Accuracy on test set: 0.8206106870229007
# 5 8 ratioInfoGain 20
# Accuracy on test set: 0.816793893129771
# 5 8 ratioInfoGain 40
# Accuracy on test set: 0.8244274809160306
# 5 8 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 5 8 gini 10
# Accuracy on test set: 0.816793893129771
# 5 8 gini 20
# Accuracy on test set: 0.7938931297709924
# 5 8 gini 40
# Accuracy on test set: 0.8015267175572519
# 5 8 gini 100
# Accuracy on test set: 0.8206106870229007
# 5 16 entropy 10
# Accuracy on test set: 0.8129770992366412
# 5 16 entropy 20
# Accuracy on test set: 0.8053435114503816
# 5 16 entropy 40
# Accuracy on test set: 0.8053435114503816
# 5 16 entropy 100
# Accuracy on test set: 0.8129770992366412
# 5 16 ratioInfoGain 10
# Accuracy on test set: 0.8320610687022901
# 5 16 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 5 16 ratioInfoGain 40
# Accuracy on test set: 0.8053435114503816
# 5 16 ratioInfoGain 100
# Accuracy on test set: 0.8320610687022901
# 5 16 gini 10
# Accuracy on test set: 0.8320610687022901
# 5 16 gini 20
# Accuracy on test set: 0.816793893129771
# 5 16 gini 40
# Accuracy on test set: 0.8206106870229007
# 5 16 gini 100
# Accuracy on test set: 0.8244274809160306
# 5 32 entropy 10
# Accuracy on test set: 0.8091603053435115
# 5 32 entropy 20
# Accuracy on test set: 0.7862595419847328
# 5 32 entropy 40
# Accuracy on test set: 0.8244274809160306
# 5 32 entropy 100
# Accuracy on test set: 0.8206106870229007
# 5 32 ratioInfoGain 10
# Accuracy on test set: 0.7824427480916031
# 5 32 ratioInfoGain 20
# Accuracy on test set: 0.8244274809160306
# 5 32 ratioInfoGain 40
# Accuracy on test set: 0.8358778625954199
# 5 32 ratioInfoGain 100
# Accuracy on test set: 0.8282442748091603
# 5 32 gini 10
# Accuracy on test set: 0.816793893129771
# 5 32 gini 20
# Accuracy on test set: 0.8053435114503816
# 5 32 gini 40
# Accuracy on test set: 0.8091603053435115
# 5 32 gini 100
# Accuracy on test set: 0.8244274809160306
# 5 64 entropy 10
# Accuracy on test set: 0.8053435114503816
# 5 64 entropy 20
# Accuracy on test set: 0.8015267175572519
# 5 64 entropy 40
# Accuracy on test set: 0.7977099236641222
# 5 64 entropy 100
# Accuracy on test set: 0.8244274809160306
# 5 64 ratioInfoGain 10
# Accuracy on test set: 0.7824427480916031
# 5 64 ratioInfoGain 20
# Accuracy on test set: 0.8320610687022901
# 5 64 ratioInfoGain 40
# Accuracy on test set: 0.8129770992366412
# 5 64 ratioInfoGain 100
# Accuracy on test set: 0.8053435114503816
# 5 64 gini 10
# Accuracy on test set: 0.7900763358778626
# 5 64 gini 20
# Accuracy on test set: 0.7824427480916031
# 5 64 gini 40
# Accuracy on test set: 0.8206106870229007
# 5 64 gini 100
# Accuracy on test set: 0.8282442748091603
# 6 1 entropy 10
# Accuracy on test set: 0.8206106870229007
# 6 1 entropy 20
# Accuracy on test set: 0.7938931297709924
# 6 1 entropy 40
# Accuracy on test set: 0.8129770992366412
# 6 1 entropy 100
# Accuracy on test set: 0.8244274809160306
# 6 1 ratioInfoGain 10
# Accuracy on test set: 0.8053435114503816
# 6 1 ratioInfoGain 20
# Accuracy on test set: 0.8129770992366412
# 6 1 ratioInfoGain 40
# Accuracy on test set: 0.8206106870229007
# 6 1 ratioInfoGain 100
# Accuracy on test set: 0.8282442748091603
# 6 1 gini 10
# Accuracy on test set: 0.8053435114503816
# 6 1 gini 20
# Accuracy on test set: 0.8129770992366412
# 6 1 gini 40
# Accuracy on test set: 0.8244274809160306
# 6 1 gini 100
# Accuracy on test set: 0.8282442748091603
# 6 4 entropy 10
# Accuracy on test set: 0.8053435114503816
# 6 4 entropy 20
# Accuracy on test set: 0.8053435114503816
# 6 4 entropy 40
# Accuracy on test set: 0.816793893129771
# 6 4 entropy 100
# Accuracy on test set: 0.8129770992366412
# 6 4 ratioInfoGain 10
# Accuracy on test set: 0.8244274809160306
# 6 4 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 6 4 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 6 4 ratioInfoGain 100
# Accuracy on test set: 0.816793893129771
# 6 4 gini 10
# Accuracy on test set: 0.816793893129771
# 6 4 gini 20
# Accuracy on test set: 0.8015267175572519
# 6 4 gini 40
# Accuracy on test set: 0.8244274809160306
# 6 4 gini 100
# Accuracy on test set: 0.8244274809160306
# 6 8 entropy 10
# Accuracy on test set: 0.8244274809160306
# 6 8 entropy 20
# Accuracy on test set: 0.8129770992366412
# 6 8 entropy 40
# Accuracy on test set: 0.8282442748091603
# 6 8 entropy 100
# Accuracy on test set: 0.8206106870229007
# 6 8 ratioInfoGain 10
# Accuracy on test set: 0.8206106870229007
# 6 8 ratioInfoGain 20
# Accuracy on test set: 0.8129770992366412
# 6 8 ratioInfoGain 40
# Accuracy on test set: 0.8206106870229007
# 6 8 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 6 8 gini 10
# Accuracy on test set: 0.8053435114503816
# 6 8 gini 20
# Accuracy on test set: 0.8244274809160306
# 6 8 gini 40
# Accuracy on test set: 0.8206106870229007
# 6 8 gini 100
# Accuracy on test set: 0.8282442748091603
# 6 16 entropy 10
# Accuracy on test set: 0.8129770992366412
# 6 16 entropy 20
# Accuracy on test set: 0.8015267175572519
# 6 16 entropy 40
# Accuracy on test set: 0.8206106870229007
# 6 16 entropy 100
# Accuracy on test set: 0.8282442748091603
# 6 16 ratioInfoGain 10
# Accuracy on test set: 0.7900763358778626
# 6 16 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 6 16 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 6 16 ratioInfoGain 100
# Accuracy on test set: 0.8282442748091603
# 6 16 gini 10
# Accuracy on test set: 0.8282442748091603
# 6 16 gini 20
# Accuracy on test set: 0.8206106870229007
# 6 16 gini 40
# Accuracy on test set: 0.816793893129771
# 6 16 gini 100
# Accuracy on test set: 0.8091603053435115
# 6 32 entropy 10
# Accuracy on test set: 0.7786259541984732
# 6 32 entropy 20
# Accuracy on test set: 0.8129770992366412
# 6 32 entropy 40
# Accuracy on test set: 0.8320610687022901
# 6 32 entropy 100
# Accuracy on test set: 0.8206106870229007
# 6 32 ratioInfoGain 10
# Accuracy on test set: 0.7938931297709924
# 6 32 ratioInfoGain 20
# Accuracy on test set: 0.8129770992366412
# 6 32 ratioInfoGain 40
# Accuracy on test set: 0.8244274809160306
# 6 32 ratioInfoGain 100
# Accuracy on test set: 0.816793893129771
# 6 32 gini 10
# Accuracy on test set: 0.8015267175572519
# 6 32 gini 20
# Accuracy on test set: 0.816793893129771
# 6 32 gini 40
# Accuracy on test set: 0.8244274809160306
# 6 32 gini 100
# Accuracy on test set: 0.8206106870229007
# 6 64 entropy 10
# Accuracy on test set: 0.7977099236641222
# 6 64 entropy 20
# Accuracy on test set: 0.8053435114503816
# 6 64 entropy 40
# Accuracy on test set: 0.8206106870229007
# 6 64 entropy 100
# Accuracy on test set: 0.816793893129771
# 6 64 ratioInfoGain 10
# Accuracy on test set: 0.7748091603053435
# 6 64 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 6 64 ratioInfoGain 40
# Accuracy on test set: 0.7977099236641222
# 6 64 ratioInfoGain 100
# Accuracy on test set: 0.8206106870229007
# 6 64 gini 10
# Accuracy on test set: 0.7862595419847328
# 6 64 gini 20
# Accuracy on test set: 0.8053435114503816
# 6 64 gini 40
# Accuracy on test set: 0.8129770992366412
# 6 64 gini 100
# Accuracy on test set: 0.8244274809160306
# 7 1 entropy 10
# Accuracy on test set: 0.8282442748091603
# 7 1 entropy 20
# Accuracy on test set: 0.8206106870229007
# 7 1 entropy 40
# Accuracy on test set: 0.7977099236641222
# 7 1 entropy 100
# Accuracy on test set: 0.8129770992366412
# 7 1 ratioInfoGain 10
# Accuracy on test set: 0.8244274809160306
# 7 1 ratioInfoGain 20
# Accuracy on test set: 0.7938931297709924
# 7 1 ratioInfoGain 40
# Accuracy on test set: 0.8091603053435115
# 7 1 ratioInfoGain 100
# Accuracy on test set: 0.8091603053435115
# 7 1 gini 10
# Accuracy on test set: 0.8053435114503816
# 7 1 gini 20
# Accuracy on test set: 0.8206106870229007
# 7 1 gini 40
# Accuracy on test set: 0.8206106870229007
# 7 1 gini 100
# Accuracy on test set: 0.8129770992366412
# 7 4 entropy 10
# Accuracy on test set: 0.816793893129771
# 7 4 entropy 20
# Accuracy on test set: 0.8129770992366412
# 7 4 entropy 40
# Accuracy on test set: 0.8206106870229007
# 7 4 entropy 100
# Accuracy on test set: 0.816793893129771
# 7 4 ratioInfoGain 10
# Accuracy on test set: 0.8091603053435115
# 7 4 ratioInfoGain 20
# Accuracy on test set: 0.8129770992366412
# 7 4 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 7 4 ratioInfoGain 100
# Accuracy on test set: 0.8206106870229007
# 7 4 gini 10
# Accuracy on test set: 0.8053435114503816
# 7 4 gini 20
# Accuracy on test set: 0.8091603053435115
# 7 4 gini 40
# Accuracy on test set: 0.816793893129771
# 7 4 gini 100
# Accuracy on test set: 0.8091603053435115
# 7 8 entropy 10
# Accuracy on test set: 0.8206106870229007
# 7 8 entropy 20
# Accuracy on test set: 0.8129770992366412
# 7 8 entropy 40
# Accuracy on test set: 0.8206106870229007
# 7 8 entropy 100
# Accuracy on test set: 0.8206106870229007
# 7 8 ratioInfoGain 10
# Accuracy on test set: 0.8053435114503816
# 7 8 ratioInfoGain 20
# Accuracy on test set: 0.8091603053435115
# 7 8 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 7 8 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 7 8 gini 10
# Accuracy on test set: 0.8206106870229007
# 7 8 gini 20
# Accuracy on test set: 0.816793893129771
# 7 8 gini 40
# Accuracy on test set: 0.816793893129771
# 7 8 gini 100
# Accuracy on test set: 0.8244274809160306
# 7 16 entropy 10
# Accuracy on test set: 0.8129770992366412
# 7 16 entropy 20
# Accuracy on test set: 0.816793893129771
# 7 16 entropy 40
# Accuracy on test set: 0.8320610687022901
# 7 16 entropy 100
# Accuracy on test set: 0.8282442748091603
# 7 16 ratioInfoGain 10
# Accuracy on test set: 0.8053435114503816
# 7 16 ratioInfoGain 20
# Accuracy on test set: 0.816793893129771
# 7 16 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 7 16 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 7 16 gini 10
# Accuracy on test set: 0.8206106870229007
# 7 16 gini 20
# Accuracy on test set: 0.816793893129771
# 7 16 gini 40
# Accuracy on test set: 0.816793893129771
# 7 16 gini 100
# Accuracy on test set: 0.8244274809160306
# 7 32 entropy 10
# Accuracy on test set: 0.7900763358778626
# 7 32 entropy 20
# Accuracy on test set: 0.8244274809160306
# 7 32 entropy 40
# Accuracy on test set: 0.8282442748091603
# 7 32 entropy 100
# Accuracy on test set: 0.8206106870229007
# 7 32 ratioInfoGain 10
# Accuracy on test set: 0.8091603053435115
# 7 32 ratioInfoGain 20
# Accuracy on test set: 0.816793893129771
# 7 32 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 7 32 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 7 32 gini 10
# Accuracy on test set: 0.8053435114503816
# 7 32 gini 20
# Accuracy on test set: 0.8053435114503816
# 7 32 gini 40
# Accuracy on test set: 0.8320610687022901
# 7 32 gini 100
# Accuracy on test set: 0.8244274809160306
# 7 64 entropy 10
# Accuracy on test set: 0.8244274809160306
# 7 64 entropy 20
# Accuracy on test set: 0.7786259541984732
# 7 64 entropy 40
# Accuracy on test set: 0.8129770992366412
# 7 64 entropy 100
# Accuracy on test set: 0.8282442748091603
# 7 64 ratioInfoGain 10
# Accuracy on test set: 0.7862595419847328
# 7 64 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 7 64 ratioInfoGain 40
# Accuracy on test set: 0.8053435114503816
# 7 64 ratioInfoGain 100
# Accuracy on test set: 0.8129770992366412
# 7 64 gini 10
# Accuracy on test set: 0.7595419847328244
# 7 64 gini 20
# Accuracy on test set: 0.8053435114503816
# 7 64 gini 40
# Accuracy on test set: 0.816793893129771
# 7 64 gini 100
# Accuracy on test set: 0.8206106870229007
# 8 1 entropy 10
# Accuracy on test set: 0.7900763358778626
# 8 1 entropy 20
# Accuracy on test set: 0.7938931297709924
# 8 1 entropy 40
# Accuracy on test set: 0.8091603053435115
# 8 1 entropy 100
# Accuracy on test set: 0.8091603053435115
# 8 1 ratioInfoGain 10
# Accuracy on test set: 0.8015267175572519
# 8 1 ratioInfoGain 20
# Accuracy on test set: 0.8091603053435115
# 8 1 ratioInfoGain 40
# Accuracy on test set: 0.7977099236641222
# 8 1 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 8 1 gini 10
# Accuracy on test set: 0.8053435114503816
# 8 1 gini 20
# Accuracy on test set: 0.8129770992366412
# 8 1 gini 40
# Accuracy on test set: 0.8129770992366412
# 8 1 gini 100
# Accuracy on test set: 0.8091603053435115
# 8 4 entropy 10
# Accuracy on test set: 0.7977099236641222
# 8 4 entropy 20
# Accuracy on test set: 0.816793893129771
# 8 4 entropy 40
# Accuracy on test set: 0.8091603053435115
# 8 4 entropy 100
# Accuracy on test set: 0.8091603053435115
# 8 4 ratioInfoGain 10
# Accuracy on test set: 0.8129770992366412
# 8 4 ratioInfoGain 20
# Accuracy on test set: 0.8053435114503816
# 8 4 ratioInfoGain 40
# Accuracy on test set: 0.7900763358778626
# 8 4 ratioInfoGain 100
# Accuracy on test set: 0.816793893129771
# 8 4 gini 10
# Accuracy on test set: 0.7938931297709924
# 8 4 gini 20
# Accuracy on test set: 0.8053435114503816
# 8 4 gini 40
# Accuracy on test set: 0.8129770992366412
# 8 4 gini 100
# Accuracy on test set: 0.8244274809160306
# 8 8 entropy 10
# Accuracy on test set: 0.816793893129771
# 8 8 entropy 20
# Accuracy on test set: 0.7938931297709924
# 8 8 entropy 40
# Accuracy on test set: 0.8129770992366412
# 8 8 entropy 100
# Accuracy on test set: 0.816793893129771
# 8 8 ratioInfoGain 10
# Accuracy on test set: 0.8282442748091603
# 8 8 ratioInfoGain 20
# Accuracy on test set: 0.7938931297709924
# 8 8 ratioInfoGain 40
# Accuracy on test set: 0.8320610687022901
# 8 8 ratioInfoGain 100
# Accuracy on test set: 0.816793893129771
# 8 8 gini 10
# Accuracy on test set: 0.8244274809160306
# 8 8 gini 20
# Accuracy on test set: 0.8206106870229007
# 8 8 gini 40
# Accuracy on test set: 0.8282442748091603
# 8 8 gini 100
# Accuracy on test set: 0.8129770992366412
# 8 16 entropy 10
# Accuracy on test set: 0.8091603053435115
# 8 16 entropy 20
# Accuracy on test set: 0.8244274809160306
# 8 16 entropy 40
# Accuracy on test set: 0.8244274809160306
# 8 16 entropy 100
# Accuracy on test set: 0.8244274809160306
# 8 16 ratioInfoGain 10
# Accuracy on test set: 0.7938931297709924
# 8 16 ratioInfoGain 20
# Accuracy on test set: 0.8206106870229007
# 8 16 ratioInfoGain 40
# Accuracy on test set: 0.8129770992366412
# 8 16 ratioInfoGain 100
# Accuracy on test set: 0.8244274809160306
# 8 16 gini 10
# Accuracy on test set: 0.8053435114503816
# 8 16 gini 20
# Accuracy on test set: 0.8129770992366412
# 8 16 gini 40
# Accuracy on test set: 0.8282442748091603
# 8 16 gini 100
# Accuracy on test set: 0.8244274809160306
# 8 32 entropy 10
# Accuracy on test set: 0.8053435114503816
# 8 32 entropy 20
# Accuracy on test set: 0.8129770992366412
# 8 32 entropy 40
# Accuracy on test set: 0.8206106870229007
# 8 32 entropy 100
# Accuracy on test set: 0.8320610687022901
# 8 32 ratioInfoGain 10
# Accuracy on test set: 0.7938931297709924
# 8 32 ratioInfoGain 20
# Accuracy on test set: 0.7824427480916031
# 8 32 ratioInfoGain 40
# Accuracy on test set: 0.816793893129771
# 8 32 ratioInfoGain 100
# Accuracy on test set: 0.8282442748091603
# 8 32 gini 10
# Accuracy on test set: 0.816793893129771
# 8 32 gini 20
# Accuracy on test set: 0.8053435114503816
# 8 32 gini 40
# Accuracy on test set: 0.8282442748091603
# 8 32 gini 100
# Accuracy on test set: 0.8282442748091603
# 8 64 entropy 10
# Accuracy on test set: 0.7977099236641222
# 8 64 entropy 20
# Accuracy on test set: 0.7824427480916031
# 8 64 entropy 40
# Accuracy on test set: 0.8091603053435115
# 8 64 entropy 100
# Accuracy on test set: 0.8206106870229007
# 8 64 ratioInfoGain 10
# Accuracy on test set: 0.8015267175572519
# 8 64 ratioInfoGain 20
# Accuracy on test set: 0.7900763358778626
# 8 64 ratioInfoGain 40
# Accuracy on test set: 0.8206106870229007
# 8 64 ratioInfoGain 100
# Accuracy on test set: 0.8091603053435115
# 8 64 gini 10
# Accuracy on test set: 0.7824427480916031
# 8 64 gini 20
# Accuracy on test set: 0.8091603053435115
# 8 64 gini 40
# Accuracy on test set: 0.8053435114503816
# 8 64 gini 100
# Accuracy on test set: 0.816793893129771
# ratioInfoGain 5 32 40
# Accuracy on train set: 0.8137535816618912
# Accuracy on test set: 0.8129770992366412

# %% [markdown]
# # Adaboost

# %%
from adaboost import Adaboost

weak_learner = DecisionTree(criterion='entropy', max_depth=2, min_samples_leaf=1, sample_feature=False)
ada = Adaboost(weak_learner=weak_learner, num_learners=50, seed=2020)
ada.fit(X, y)

y_train_pred = ada.predict(X)

print("Accuracy on train set: {}".format(accuracy(y, y_train_pred)))
# Out:
# Accuracy on train set: 0.7793696275071633

# %%
# hyper-parameters such as max_depth, and min_samples_in_leaf 
# according to the cross-validation result.
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=2020)
criters=['entropy', 'ratioInfoGain','gini']
depths=[3, 4, 5, 6, 7, 8]
leaves=[1, 4, 8, 16, 32, 64]
estimators=[10, 20, 50, 100]
bestCriter=criters[0]
bestDepth=depths[0]
bestLeaf=leaves[0]
best_estimator=estimators[0]
bestScore=0.0
for depth in depths:
    for leaf in leaves:
        for criter in criters:
            for estimator in estimators:
                print('{} {} {} {}'.format(depth, leaf, criter, estimator))
                weak_learner = DecisionTree(criterion=criter, max_depth=depth, min_samples_leaf=leaf, sample_feature=False)
                ada = Adaboost(weak_learner=weak_learner, num_learners=estimator, seed=2020)
                pred=np.zeros(len(X))
                for train_indice, valid_indice in kf.split(X, y):
                    X_train_fold, y_train_fold = X.loc[train_indice], y.loc[train_indice]
                    X_val_fold, y_val_fold = X.loc[valid_indice], y.loc[valid_indice]
                    # print(X_train_fold.shape, X_val_fold.shape)
                    ada.fit(X_train_fold, y_train_fold)
                    pred[valid_indice]=ada.predict(X_val_fold)
                score=accuracy(y, pred)
                if score>bestScore:
                    bestScore=score
                    bestCriter=criter
                    bestDepth=depth
                    bestLeaf=leaf
                    best_estimator=estimator
                print("Accuracy on validation set: {}".format(score))
print('{} {} {} {}'.format(bestCriter, bestDepth, bestLeaf, best_estimator))
weak_learner = DecisionTree(criterion=bestCriter, max_depth=bestDepth, min_samples_leaf=bestLeaf, sample_feature=False)
ada = Adaboost(weak_learner=weak_learner, num_learners=best_estimator, seed=2020)
ada.fit(X, y)
print("Accuracy on train set: {}".format(accuracy(y, ada.predict(X))))
print("Accuracy on test set: {}".format(accuracy(y_test, ada.predict(X_test))))
# Out:
# 3 1 entropy 10
# Accuracy on validation set: 0.7984718242597899
# 3 1 entropy 20
# Accuracy on validation set: 0.7984718242597899
# 3 1 entropy 50
# Accuracy on validation set: 0.7984718242597899
# 3 1 entropy 100
# Accuracy on validation set: 0.7984718242597899
# 3 1 ratioInfoGain 10
# Accuracy on validation set: 0.7908309455587392
# 3 1 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 3 1 ratioInfoGain 50
# Accuracy on validation set: 0.7908309455587392
# 3 1 ratioInfoGain 100
# Accuracy on validation set: 0.7908309455587392
# 3 1 gini 10
# Accuracy on validation set: 0.8022922636103151
# 3 1 gini 20
# Accuracy on validation set: 0.8003820439350525
# 3 1 gini 50
# Accuracy on validation set: 0.8022922636103151
# 3 1 gini 100
# Accuracy on validation set: 0.8013371537726839
# 3 4 entropy 10
# Accuracy on validation set: 0.7984718242597899
# 3 4 entropy 20
# Accuracy on validation set: 0.7984718242597899
# 3 4 entropy 50
# Accuracy on validation set: 0.7984718242597899
# 3 4 entropy 100
# Accuracy on validation set: 0.7984718242597899
# 3 4 ratioInfoGain 10
# Accuracy on validation set: 0.7908309455587392
# 3 4 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 3 4 ratioInfoGain 50
# Accuracy on validation set: 0.7908309455587392
# 3 4 ratioInfoGain 100
# Accuracy on validation set: 0.7908309455587392
# 3 4 gini 10
# Accuracy on validation set: 0.8022922636103151
# 3 4 gini 20
# Accuracy on validation set: 0.8003820439350525
# 3 4 gini 50
# Accuracy on validation set: 0.8022922636103151
# 3 4 gini 100
# Accuracy on validation set: 0.8013371537726839
# 3 8 entropy 10
# Accuracy on validation set: 0.7984718242597899
# 3 8 entropy 20
# Accuracy on validation set: 0.7984718242597899
# 3 8 entropy 50
# Accuracy on validation set: 0.7984718242597899
# 3 8 entropy 100
# Accuracy on validation set: 0.7984718242597899
# 3 8 ratioInfoGain 10
# Accuracy on validation set: 0.7908309455587392
# 3 8 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 3 8 ratioInfoGain 50
# Accuracy on validation set: 0.7908309455587392
# 3 8 ratioInfoGain 100
# Accuracy on validation set: 0.7908309455587392
# 3 8 gini 10
# Accuracy on validation set: 0.8022922636103151
# 3 8 gini 20
# Accuracy on validation set: 0.8003820439350525
# 3 8 gini 50
# Accuracy on validation set: 0.8022922636103151
# 3 8 gini 100
# Accuracy on validation set: 0.8013371537726839
# 3 16 entropy 10
# Accuracy on validation set: 0.7965616045845272
# 3 16 entropy 20
# Accuracy on validation set: 0.7965616045845272
# 3 16 entropy 50
# Accuracy on validation set: 0.7965616045845272
# 3 16 entropy 100
# Accuracy on validation set: 0.7965616045845272
# 3 16 ratioInfoGain 10
# Accuracy on validation set: 0.7908309455587392
# 3 16 ratioInfoGain 20
# Accuracy on validation set: 0.7908309455587392
# 3 16 ratioInfoGain 50
# Accuracy on validation set: 0.7908309455587392
# 3 16 ratioInfoGain 100

# %%
#simple comparsion of different models
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

models=[
        DecisionTreeClassifier(),
        RandomForestClassifier(n_estimators=500),
        AdaBoostClassifier(n_estimators=500), 
        GradientBoostingClassifier(n_estimators=120,learning_rate=0.12,max_depth=4)]
names=['Decision Trees','Random Forests','Boosting','Gradient Boosting Classifier']
for name,model in zip(names,models):
    score=cross_val_score(model,X,y,cv=5)
    print("{}: {},{}".format(name,score.mean(),score))

# %% [markdown]
# ## References
#
# ### Tree plotter - https://github.com/pbharrin/machinelearninginaction/blob/master/Ch03/treePlotter.py
# ### Titanic Dataset - https://www.kaggle.com/code/dmilla/introduction-to-decision-trees-titanic-dataset
# ### Decision tree - https://github.com/marcus58/Ensemble-Model-of-Decision-Tree/blob/master/decision_tree.py
